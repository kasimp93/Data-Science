# %% [markdown]
# # Stack Overflow

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this assignment, we will use some posts on Stack Overflow during the year of 2015 and measure the similarity of  users by looking at their answers' score. In order to get a full grade, do not delete the output of your code cells. This assignment is to be completed **INDIVIDUALLY** and is due on **September 29**.
#
# Please update the README with your BU username.

# %% [markdown]
# ## Step 0. Preparation

# %% [markdown]
# Before we start working on the notebook, let's make sure that everything is setup properly. You should have downloaded and installed
# * [Anaconda](https://store.continuum.io/cshop/anaconda/)
# * [Git](http://git-scm.com/downloads)
#
# If you are working from the undergraduate lab (on a linux machine) these are both installed, but you need to follow the instructions [from here](https://github.com/mcrovella/CS505-Computational-Tools-for-Data-Science/blob/master/2-Getting-Started.ipynb).

# %% [markdown]
# ## Step 1. Getting the data

# %% [markdown]
# Let's make a sample request to retrieve some questions posted on Stack Exchange on the first day of 2015. Documentation of the Stack Exchange API can be found [here](https://api.stackexchange.com/docs). You might need to install the *requests* library and an easy way to do so is by using the command [pip](https://docs.python.org/3/installing/index.html).

# %%
import requests
from datetime import datetime

start_time = 1420070400 # 01-01-2015 at 00:00:00
end_time   = 1420156800 # 01-02-2015 at 00:00:00
max_pages = 100

# response = requests.get("https://api.stackexchange.com/2.2/questions?pagesize=100" + "&pageNo=" + str(page_no))
#                         "&fromdate=" + str(start_time) + "&todate=" + str(end_time) +
#                         "&order=asc&sort=creation&site=stackoverflow")

response = requests.get("https://api.stackexchange.com/2.2/questions?pagesize=100" +
                    "&fromdate=" + str(start_time) + "&todate=" + str(end_time) +
                    "&order=asc&sort=creation&site=stackoverflow")

print(response)
type(response)
# Out:
# <Response [200]>
# requests.models.Response

# %% [markdown]
# Now, object *response* contains the raw text of posts from the first day of 2015.
# Note that all dates in the Stack Exchange API are in [unix epoch time](https://en.wikipedia.org/wiki/Unix_time). The format for the request string is specified [here](https://api.stackexchange.com/docs/questions).

# %% [markdown]
# We can try to print the response that Stack Exchange returns.

# %%
print(response.text)
# Out:
# {"items":[{"tags":["php","mysql","arrays","mysqli"],"owner":{"reputation":230,"user_id":3210431,"user_type":"registered","accept_rate":78,"profile_image":"https://i.stack.imgur.com/QTjBV.jpg?s=128&g=1","display_name":"salep","link":"https://stackoverflow.com/users/3210431/salep"},"is_answered":true,"view_count":247,"accepted_answer_id":27727478,"answer_count":2,"score":0,"last_activity_date":1420071815,"creation_date":1420070458,"question_id":27727385,"link":"https://stackoverflow.com/questions/27727385/inserting-multiple-records-into-mysql-from-an-array","title":"Inserting multiple records into MySQL from an array"},{"tags":["apache-pig"],"owner":{"reputation":6,"user_id":868779,"user_type":"registered","profile_image":"https://www.gravatar.com/avatar/19f7315b44e97ca1bc069694fdba7428?s=128&d=identicon&r=PG","display_name":"Balpreet Pankaj","link":"https://stackoverflow.com/users/868779/balpreet-pankaj"},"is_answered":false,"view_count":920,"answer_count":1,"score":1,"last_activity_date":1430411692,"creation_date":1420070503,"question_id":27727388,"link":"https://stackoverflow.com/questions/27727388/apache-pig-classcast-exception-when-loading-data-with-schema","title":"Apache Pig ClassCast exception when loading data with schema"},{"tags":["ios","xcode","swift"],"owner":{"reputation":68,"user_id":4372672,"user_type":"registered","accept_rate":100,"profile_image":"https://www.gravatar.com/avatar/b280aaec38444447cf50e471b2f201f3?s=128&d=identicon&r=PG&f=1","display_name":"mres","link":"https://stackoverflow.com/users/4372672/mres"},"is_answered":true,"view_count":179,"accepted_answer_id":27727456,"answer_count":1,"score":1,"last_activity_date":1420071363,"creation_date":1420070552,"question_id":27727391,"link":"https://stackoverflow.com/questions/27727391/simplify-dictionary-xcode-keeps-indexing-forever","title":"Simplify dictionary (xcode keeps indexing forever)"},{"tags":["sql-server","cross-apply"],"owner":{"reputation":136,"user_id":2482149,"user_type":"registered","accept_rate":44,"profile_image":"https://www.gravatar.com/avatar/14b443f6010c1625e6a020188b6ffec8?s=128&d=identicon&r=PG","display_name":"clattenburg cake","link":"https://stackoverflow.com/users/2482149/clattenburg-cake"},"is_answered":true,"view_count":81,"accepted_answer_id":27728236,"answer_count":1,"score":3,"last_activity_date":1420086485,"creation_date":1420070577,"question_id":27727393,"link":"https://stackoverflow.com/questions/27727393/cross-apply-at-different-level","title":"Cross Apply At Different Level"},{"tags":["php"],"owner":{"reputation":7,"user_id":4263870,"user_type":"registered","profile_image":"https://www.gravatar.com/avatar/313c043fe5a444a6fe7b0a222451557c?s=128&d=identicon&r=PG&f=1","display_name":"Solution Developer","link":"https://stackoverflow.com/users/4263870/solution-developer"},"is_answered":true,"view_count":738,"closed_date":1420075251,"answer_count":2,"score":-3,"last_activity_date":1420072891,"creation_date":1420070611,"question_id":27727394,"link":"https://stackoverflow.com/questions/27727394/php-macro-substitution","closed_reason":"unclear what you&#39;re asking","title":"PHP Macro Substitution"},{"tags":["android"],"owner":{"reputation":1,"user_id":4409381,"user_type":"registered","profile_image":"https://lh6.googleusercontent.com/-tLlhoS7DEjg/AAAAAAAAAAI/AAAAAAAABLI/JqSpN-uO3zs/photo.jpg?sz=128","display_name":"Troy Pavlek","link":"https://stackoverflow.com/users/4409381/troy-pavlek"},"is_answered":false,"view_count":196,"answer_count":0,"score":0,"last_activity_date":1420073263,"creation_date":1420070641,"last_edit_date":1420073263,"question_id":27727396,"link":"https://stackoverflow.com/questions/27727396/computing-the-intersection-between-a-line-and-a-circular-path-in-android","title":"Computing the intersection between a line and a circular path in Android"},{"tags":["c#","combobox","nullreferenceexception","crash-reports","dropdownbox"],"owner":{"reputation":1469,"user_id":875317,"user_type":"registered","accept_rate" ...

# %% [markdown]
# It is not possible to read the raw response. Instead, we need to decode the raw response as **JSON** and use the `json` library to print it. JavaScript Object Notation (JSON) is a standard text-based format for representing structured data based on JavaScript object syntax, which is commonly used for representing and transmitting data on web sites. More documentation on json objects can be found [here](https://developer.mozilla.org/en-US/docs/Learn/JavaScript/Objects/JSON)

# %%
import json
json_response = response.json()

print(json.dumps(json_response, indent=1))
#print(json_response["has_more"])
# Out:
# {
#  "quota_max": 300,
#  "quota_remaining": 298,
#  "has_more": true,
#  "items": [
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727478,
#    "owner": {
#     "display_name": "salep",
#     "link": "https://stackoverflow.com/users/3210431/salep",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/QTjBV.jpg?s=128&g=1",
#     "reputation": 230,
#     "accept_rate": 78,
#     "user_id": 3210431
#    },
#    "link": "https://stackoverflow.com/questions/27727385/inserting-multiple-records-into-mysql-from-an-array",
#    "answer_count": 2,
#    "creation_date": 1420070458,
#    "view_count": 247,
#    "question_id": 27727385,
#    "title": "Inserting multiple records into MySQL from an array",
#    "tags": [
#     "php",
#     "mysql",
#     "arrays",
#     "mysqli"
#    ],
#    "score": 0,
#    "last_activity_date": 1420071815
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Balpreet Pankaj",
#     "link": "https://stackoverflow.com/users/868779/balpreet-pankaj",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/19f7315b44e97ca1bc069694fdba7428?s=128&d=identicon&r=PG",
#     "reputation": 6,
#     "user_id": 868779
#    },
#    "link": "https://stackoverflow.com/questions/27727388/apache-pig-classcast-exception-when-loading-data-with-schema",
#    "tags": [
#     "apache-pig"
#    ],
#    "creation_date": 1420070503,
#    "score": 1,
#    "last_activity_date": 1430411692,
#    "view_count": 920,
#    "question_id": 27727388,
#    "title": "Apache Pig ClassCast exception when loading data with schema"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727456,
#    "owner": {
#     "display_name": "mres",
#     "link": "https://stackoverflow.com/users/4372672/mres",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/b280aaec38444447cf50e471b2f201f3?s=128&d=identicon&r=PG&f=1",
#     "reputation": 68,
#     "accept_rate": 100,
#     "user_id": 4372672
#    },
#    "link": "https://stackoverflow.com/questions/27727391/simplify-dictionary-xcode-keeps-indexing-forever",
#    "answer_count": 1,
#    "creation_date": 1420070552,
#    "view_count": 179,
#    "question_id": 27727391,
#    "title": "Simplify dictionary (xcode keeps indexing forever)",
#    "tags": [
#     "ios",
#     "xcode",
#     "swift"
#    ],
#    "score": 1,
#    "last_activity_date": 1420071363
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27728236,
#    "owner": {
#     "display_name": "clattenburg cake",
#     "link": "https://stackoverflow.com/users/2482149/clattenburg-cake",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/14b443f6010c1625e6a020188b6ffec8?s=128&d=identicon&r=PG",
#     "reputation": 136,
#     "accept_rate": 44,
#     "user_id": 2482149
#    },
#    "link": "https://stackoverflow.com/questions/27727393/cross-apply-at-different-level",
#    "answer_count": 1,
#    "creation_date": 1420070577,
#    "view_count": 81,
#    "question_id": 27727393,
#    "title": "Cross Apply At Different Level",
#    "tags": [
#     "sql-server",
#     "cross-apply"
#    ],
#    "score": 3,
#    "last_activity_date": 1420086485
#   },
#   {
#    "is_answered": true,
#    "creation_date": 1420070611,
#    "closed_reason": "unclear what you&#39;re asking",
#    "owner": {
#     "display_name": "Solution Developer",
#     "link": "https://stackoverflow.com/users/4263870/solution-developer",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/313c043fe5a444a6fe7b0a222451557c?s=128&d=identicon&r=PG&f=1",
#     "reputation": 7,
#     "user_id": 4263870
#    },
#    "link": "https://stackoverflow.com/questions/27727394/php-macro-substitution",
#    "answer_count": 2,
#    "view_count": 738,
#    "question_id": 27727394,
#    "closed_date": 1420075251,
#    "tags": [
#     "php"
#    ],
#    "score": -3,
#    "last_activity_date": 1420072891,
#    "title": "PHP Macro Substitution"
#   },
#   {
#    "is_answered": false,
#    "answer_count": 0,
#    "owner": {
#     "display_name": "Troy Pavlek",
#     "link": "https://stackoverflow.com/users/4409381/troy-pavlek",
#     "user_type": "registered",
#     "profile_image": "https://lh6.googleusercontent.com/-tLlhoS7DEjg/AAAAAAAAAAI/AAAAAAAABLI/JqSpN-uO3zs/photo.jpg?sz=128",
#     "reputation": 1,
#     "user_id": 4409381
#    },
#    "tags": [
#     "android"
#    ],
#    "creation_date": 1420070641,
#    "view_count": 196,
#    "question_id": 27727396,
#    "last_edit_date": 1420073263,
#    "title": "Computing the intersection between a line and a circular path in Android",
#    "link": "https://stackoverflow.com/questions/27727396/computing-the-intersection-between-a-line-and-a-circular-path-in-android",
#    "score": 0,
#    "last_activity_date": 1420073263
#   },
#   {
#    "is_answered": false,
#    "answer_count": 0,
#    "owner": {
#     "display_name": "B. Clay Shannon",
#     "link": "https://stackoverflow.com/users/875317/b-clay-shannon",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/FBuZL.jpg?s=128&g=1",
#     "reputation": 1469,
#     "accept_rate": 97,
#     "user_id": 875317
#    },
#    "tags": [
#     "c#",
#     "combobox",
#     "nullreferenceexception",
#     "crash-reports",
#     "dropdownbox"
#    ],
#    "creation_date": 1420070703,
#    "view_count": 233,
#    "question_id": 27727406,
#    "last_edit_date": 1422398311,
#    "title": "Why would dropping down a populated combo box crash a form?",
#    "link": "https://stackoverflow.com/questions/27727406/why-would-dropping-down-a-populated-combo-box-crash-a-form",
#    "score": 3,
#    "last_activity_date": 1422398311
#   },
#   {
#    "is_answered": true,
#    "answer_count": 2,
#    "owner": {
#     "display_name": "bernie2436",
#     "link": "https://stackoverflow.com/users/821742/bernie2436",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/e864faa75e9b04c70e6e1db43ad9391b?s=128&d=identicon&r=PG&f=1",
#     "reputation": 5025,
#     "accept_rate": 72,
#     "user_id": 821742
#    },
#    "tags": [
#     "java"
#    ],
#    "creation_date": 1420070727,
#    "view_count": 273,
#    "question_id": 27727407,
#    "last_edit_date": 1495542740,
#    "title": "Could not find or load main class: what steps are next for debugging?",
#    "link": "https://stackoverflow.com/questions/27727407/could-not-find-or-load-main-class-what-steps-are-next-for-debugging",
#    "score": -1,
#    "last_activity_date": 1471863533
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727502,
#    "owner": {
#     "display_name": "user9993",
#     "link": "https://stackoverflow.com/users/2595033/user9993",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/bd78391e14ec16fe30d2e1811a841c70?s=128&d=identicon&r=PG",
#     "reputation": 810,
#     "accept_rate": 48,
#     "user_id": 2595033
#    },
#    "link": "https://stackoverflow.com/questions/27727408/c-portable-class-libraries-using-images",
#    "answer_count": 1,
#    "creation_date": 1420070734,
#    "view_count": 1040,
#    "question_id": 27727408,
#    "title": "C# Portable Class Libraries - Using images",
#    "tags": [
#     "c#",
#     ".net"
#    ],
#    "score": 1,
#    "last_activity_date": 1420075568
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "gfree",
#     "link": "https://stackoverflow.com/users/1815395/gfree",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/1536a9ac7a95452ab268304c1f28c957?s=128&d=identicon&r=PG",
#     "reputation": 64,
#     "accept_rate": 56,
#     "user_id": 1815395
#    },
#    "tags": [
#     "apache",
#     "redirect"
#    ],
#    "creation_date": 1420070777,
#    "view_count": 351,
#    "question_id": 27727409,
#    "last_edit_date": 1420072016,
#    "title": "apache redirect loop in virtual host",
#    "link": "https://stackoverflow.com/questions/27727409/apache-redirect-loop-in-virtual-host",
#    "score": 1,
#    "last_activity_date": 1420230044
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727428,
#    "owner": {
#     "display_name": "Michael Berkowski",
#     "link": "https://stackoverflow.com/users/541091/michael-berkowski",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/cd0165a88a06fc92a36f222606f17a11?s=128&d=identicon&r=PG",
#     "reputation": 201176,
#     "accept_rate": 100,
#     "user_id": 541091
#    },
#    "link": "https://stackoverflow.com/questions/27727410/can-sequel-be-forced-to-always-return-autoincrement-id-with-on-duplicate-key-upd",
#    "answer_count": 1,
#    "creation_date": 1420070801,
#    "view_count": 405,
#    "question_id": 27727410,
#    "last_edit_date": 1424894517,
#    "title": "Can Sequel be forced to always return autoincrement id with ON DUPLICATE KEY UPDATE?",
#    "tags": [
#     "mysql",
#     "ruby",
#     "sequel",
#     "on-duplicate-key"
#    ],
#    "score": 0,
#    "last_activity_date": 1424894517
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27732396,
#    "owner": {
#     "display_name": "Harshal Pandya",
#     "link": "https://stackoverflow.com/users/1210038/harshal-pandya",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/abrMz.jpg?s=128&g=1",
#     "reputation": 1176,
#     "accept_rate": 53,
#     "user_id": 1210038
#    },
#    "link": "https://stackoverflow.com/questions/27727414/render-view-on-click-event",
#    "answer_count": 1,
#    "creation_date": 1420070848,
#    "view_count": 158,
#    "question_id": 27727414,
#    "title": "Render view on click event",
#    "tags": [
#     "javascript",
#     "backbone.js",
#     "marionette"
#    ],
#    "score": 0,
#    "last_activity_date": 1444993111
#   },
#   {
#    "is_answered": true,
#    "creation_date": 1420070859,
#    "closed_reason": "off-topic",
#    "owner": {
#     "display_name": "Qlii256",
#     "link": "https://stackoverflow.com/users/3674356/qlii256",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/547c660c50f73a3e0c45affe66db5965?s=128&d=identicon&r=PG&f=1",
#     "reputation": 38,
#     "accept_rate": 50,
#     "user_id": 3674356
#    },
#    "link": "https://stackoverflow.com/questions/27727418/ajax-call-on-codeigniter-controller-results-in-403-forbidden",
#    "answer_count": 1,
#    "accepted_answer_id": 27727685,
#    "view_count": 2952,
#    "question_id": 27727418,
#    "last_edit_date": 1420074774,
#    "closed_date": 1420125656,
#    "tags": [
#     "php",
#     "jquery",
#     "ajax",
#     "codeigniter"
#    ],
#    "score": 0,
#    "last_activity_date": 1420075264,
#    "title": "Ajax call on CodeIgniter controller results in 403 Forbidden"
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "kakridge",
#     "link": "https://stackoverflow.com/users/347062/kakridge",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/f251dbbf4025079632a5c18c0db2f5b4?s=128&d=identicon&r=PG",
#     "reputation": 1153,
#     "accept_rate": 91,
#     "user_id": 347062
#    },
#    "link": "https://stackoverflow.com/questions/27727419/verticall-align-two-headers-of-different-sizes",
#    "tags": [
#     "html",
#     "css"
#    ],
#    "creation_date": 1420070866,
#    "score": 0,
#    "last_activity_date": 1420070979,
#    "view_count": 46,
#    "question_id": 27727419,
#    "title": "Verticall Align Two Headers of Different Sizes"
#   },
#   {
#    "is_answered": true,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Marty W",
#     "link": "https://stackoverflow.com/users/1254618/marty-w",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/848b47d40e485c90bea4709e48cf8771?s=128&d=identicon&r=PG",
#     "reputation": 195,
#     "accept_rate": 40,
#     "user_id": 1254618
#    },
#    "link": "https://stackoverflow.com/questions/27727424/controlling-playback-in-scenekit-animations",
#    "tags": [
#     "collada",
#     "scenekit"
#    ],
#    "creation_date": 1420070968,
#    "score": 1,
#    "last_activity_date": 1420212968,
#    "view_count": 549,
#    "question_id": 27727424,
#    "title": "Controlling playback in scenekit Animations"
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Ben Walsh",
#     "link": "https://stackoverflow.com/users/3412951/ben-walsh",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/fa5b080db313e36b4b33453800b0930a?s=128&d=identicon&r=PG&f=1",
#     "reputation": 21,
#     "user_id": 3412951
#    },
#    "link": "https://stackoverflow.com/questions/27727427/factorygirl-belongs-to-association-and-validates-presence-of-failing-foreign",
#    "tags": [
#     "ruby-on-rails",
#     "rspec",
#     "associations",
#     "factory-girl",
#     "belongs-to"
#    ],
#    "creation_date": 1420071005,
#    "score": 2,
#    "last_activity_date": 1420078309,
#    "view_count": 566,
#    "question_id": 27727427,
#    "title": "FactoryGirl belongs_to association and validates_presence_of failing -- foreign key is associated, object is not"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27749886,
#    "owner": {
#     "display_name": "reydelleon",
#     "link": "https://stackoverflow.com/users/1743377/reydelleon",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/xtXk2.jpg?s=128&g=1",
#     "reputation": 545,
#     "accept_rate": 90,
#     "user_id": 1743377
#    },
#    "link": "https://stackoverflow.com/questions/27727429/how-to-get-chrome-runtime-oninstalled-to-fire-when-using-require-js-in-chrome-ex",
#    "answer_count": 1,
#    "creation_date": 1420071029,
#    "view_count": 1117,
#    "question_id": 27727429,
#    "title": "How to get chrome.runtime.onInstalled to fire when using Require.JS in Chrome extension",
#    "tags": [
#     "javascript",
#     "google-chrome",
#     "events",
#     "google-chrome-extension",
#     "requirejs"
#    ],
#    "score": 3,
#    "last_activity_date": 1420240749
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27729675,
#    "owner": {
#     "display_name": "Lance Pollard",
#     "link": "https://stackoverflow.com/users/169992/lance-pollard",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/3rvks.jpg?s=128&g=1",
#     "reputation": 27775,
#     "accept_rate": 85,
#     "user_id": 169992
#    },
#    "link": "https://stackoverflow.com/questions/27727433/how-is-baremetalos-allocating-memory-in-assembly-without-malloc-brk-or-mmap",
#    "answer_count": 3,
#    "creation_date": 1420071103,
#    "view_count": 614,
#    "question_id": 27727433,
#    "last_edit_date": 1420135560,
#    "title": "How is BareMetalOS allocating memory in Assembly without malloc, brk, or mmap?",
#    "tags": [
#     "c",
#     "assembly",
#     "memory-management"
#    ],
#    "score": 0,
#    "last_activity_date": 1420135560
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727460,
#    "owner": {
#     "display_name": "stillAFanOfTheSimpsons",
#     "link": "https://stackoverflow.com/users/4056620/stillafanofthesimpsons",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/6498e2aad1e950ef9f0f6e4264f71a6d?s=128&d=identicon&r=PG&f=1",
#     "reputation": 73,
#     "accept_rate": 68,
#     "user_id": 4056620
#    },
#    "link": "https://stackoverflow.com/questions/27727434/declaring-an-array-of-objects-in-objective-c",
#    "answer_count": 2,
#    "creation_date": 1420071122,
#    "view_count": 64,
#    "question_id": 27727434,
#    "last_edit_date": 1420072994,
#    "title": "Declaring an array of objects in objective c",
#    "tags": [
#     "ios",
#     "objective-c",
#     "arrays",
#     "object",
#     "nsarray"
#    ],
#    "score": -2,
#    "last_activity_date": 1420072994
#   },
#   {
#    "is_answered": true,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Coty",
#     "link": "https://stackoverflow.com/users/2993567/coty",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/c51c94927fb5f20e87f39e57f65360e9?s=128&d=identicon&r=PG&f=1",
#     "reputation": 45,
#     "accept_rate": 60,
#     "user_id": 2993567
#    },
#    "link": "https://stackoverflow.com/questions/27727439/how-to-watch-for-transactions-for-an-address-in-bitcoinj-java",
#    "tags": [
#     "java",
#     "bitcoin",
#     "bitcoinj"
#    ],
#    "creation_date": 1420071175,
#    "score": 2,
#    "last_activity_date": 1420074027,
#    "view_count": 841,
#    "question_id": 27727439,
#    "title": "How to watch for transactions for an address in Bitcoinj (java)?"
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Nandy",
#     "link": "https://stackoverflow.com/users/3085148/nandy",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/72a1cf1d609df879424f4fdaf40ca12c?s=128&d=identicon&r=PG&f=1",
#     "reputation": 5,
#     "user_id": 3085148
#    },
#    "tags": [
#     "powershell"
#    ],
#    "creation_date": 1420071184,
#    "view_count": 637,
#    "question_id": 27727442,
#    "last_edit_date": 1420293001,
#    "title": "Saving webpage content into variables",
#    "link": "https://stackoverflow.com/questions/27727442/saving-webpage-content-into-variables",
#    "score": 0,
#    "last_activity_date": 1420293001
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Mike Nguyen",
#     "link": "https://stackoverflow.com/users/2457761/mike-nguyen",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/7d7050f24610c0dc825a8d1d3f8bb15e?s=128&d=identicon&r=PG",
#     "reputation": 28,
#     "accept_rate": 29,
#     "user_id": 2457761
#    },
#    "tags": [
#     "java",
#     "mysql"
#    ],
#    "creation_date": 1420071212,
#    "view_count": 124,
#    "question_id": 27727444,
#    "last_edit_date": 1420082939,
#    "title": "MySQL database unable to connection",
#    "link": "https://stackoverflow.com/questions/27727444/mysql-database-unable-to-connection",
#    "score": 0,
#    "last_activity_date": 1420082939
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Anshuman Pattnaik",
#     "link": "https://stackoverflow.com/users/4371259/anshuman-pattnaik",
#     "user_type": "registered",
#     "profile_image": "https://lh6.googleusercontent.com/-XjN1W9MfgOw/AAAAAAAAAAI/AAAAAAAAADI/_-9Y_nMVC-I/photo.jpg?sz=128",
#     "reputation": 34,
#     "accept_rate": 25,
#     "user_id": 4371259
#    },
#    "link": "https://stackoverflow.com/questions/27727446/why-multiparty-form-is-creating-some-temporary-image-file-after-upload",
#    "tags": [
#     "node.js",
#     "multipartform-data"
#    ],
#    "creation_date": 1420071230,
#    "score": 0,
#    "last_activity_date": 1420076102,
#    "view_count": 579,
#    "question_id": 27727446,
#    "title": "why multiparty.Form() is creating some temporary image file after upload?"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27850524,
#    "owner": {
#     "display_name": "Zenton",
#     "link": "https://stackoverflow.com/users/3802790/zenton",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/bb81e22ee264e3290d78a6a8f41b45f8?s=128&d=identicon&r=PG&f=1",
#     "reputation": 332,
#     "accept_rate": 29,
#     "user_id": 3802790
#    },
#    "link": "https://stackoverflow.com/questions/27727455/class-x-is-implemented-in-both-framework-and-application-one-of-the-two-will",
#    "answer_count": 4,
#    "creation_date": 1420071340,
#    "view_count": 7267,
#    "question_id": 27727455,
#    "last_edit_date": 1420109480,
#    "title": "Class X is implemented in both &lt;framework&gt; and &lt;application&gt; one of the two will be used, which one is undefined",
#    "tags": [
#     "ios",
#     "cocoapods",
#     "ios-frameworks"
#    ],
#    "score": 29,
#    "last_activity_date": 1464845671
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727618,
#    "owner": {
#     "display_name": "Unheilig",
#     "link": "https://stackoverflow.com/users/2227834/unheilig",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/7rqSI.png?s=128&g=1",
#     "reputation": 10670,
#     "accept_rate": 62,
#     "user_id": 2227834
#    },
#    "link": "https://stackoverflow.com/questions/27727459/finding-size-without-using-sizeof",
#    "answer_count": 4,
#    "creation_date": 1420071431,
#    "view_count": 723,
#    "question_id": 27727459,
#    "last_edit_date": 1450265474,
#    "title": "Finding size without using sizeof",
#    "tags": [
#     "c",
#     "sizeof"
#    ],
#    "score": 1,
#    "last_activity_date": 1450265474
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727527,
#    "owner": {
#     "display_name": "Trent H",
#     "link": "https://stackoverflow.com/users/4397115/trent-h",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/17510118cb38348f421198dd4a236bd5?s=128&d=identicon&r=PG&f=1",
#     "reputation": 5,
#     "user_id": 4397115
#    },
#    "link": "https://stackoverflow.com/questions/27727464/javascript-validate-select-list",
#    "answer_count": 3,
#    "creation_date": 1420071530,
#    "view_count": 4947,
#    "question_id": 27727464,
#    "last_edit_date": 1420071846,
#    "title": "JavaScript Validate Select List",
#    "tags": [
#     "javascript",
#     "forms",
#     "validation",
#     "select"
#    ],
#    "score": 0,
#    "last_activity_date": 1420074231
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "yamski",
#     "link": "https://stackoverflow.com/users/3494499/yamski",
#     "user_type": "registered",
#     "profile_image": "https://graph.facebook.com/1294655334/picture?type=large",
#     "reputation": 194,
#     "accept_rate": 71,
#     "user_id": 3494499
#    },
#    "tags": [
#     "ios",
#     "objective-c",
#     "iphone",
#     "nsurlconnection",
#     "nsurlrequest"
#    ],
#    "creation_date": 1420071736,
#    "view_count": 142,
#    "question_id": 27727468,
#    "last_edit_date": 1420123082,
#    "title": "NSURLConnection/Session. GET request. sending parameters as data, and not part of the URL",
#    "link": "https://stackoverflow.com/questions/27727468/nsurlconnection-session-get-request-sending-parameters-as-data-and-not-part-o",
#    "score": 0,
#    "last_activity_date": 1420127043
#   },
#   {
#    "is_answered": true,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "user3286192",
#     "link": "https://stackoverflow.com/users/3286192/user3286192",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/e29e5dab9209f65e144de33c491292f4?s=128&d=identicon&r=PG&f=1",
#     "reputation": 25,
#     "accept_rate": 50,
#     "user_id": 3286192
#    },
#    "tags": [
#     "android",
#     "google-cardboard"
#    ],
#    "creation_date": 1420071794,
#    "view_count": 838,
#    "question_id": 27727477,
#    "last_edit_date": 1420106173,
#    "title": "Move in the direction the VR window is pointing",
#    "link": "https://stackoverflow.com/questions/27727477/move-in-the-direction-the-vr-window-is-pointing",
#    "score": 1,
#    "last_activity_date": 1420347465
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727499,
#    "owner": {
#     "display_name": "Hello lad",
#     "link": "https://stackoverflow.com/users/2999675/hello-lad",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/cb0b7c8c3b13457a7cb7749d1334d3ae?s=128&d=identicon&r=PG&f=1",
#     "reputation": 2663,
#     "accept_rate": 71,
#     "user_id": 2999675
#    },
#    "link": "https://stackoverflow.com/questions/27727481/why-i-can-not-put-cin-cout-in-a-function-and-call-that-function-from-main",
#    "answer_count": 2,
#    "creation_date": 1420071830,
#    "view_count": 107,
#    "question_id": 27727481,
#    "last_edit_date": 1420072253,
#    "title": "Why I can not put cin/cout in a function and call that function from main()",
#    "tags": [
#     "c++"
#    ],
#    "score": 0,
#    "last_activity_date": 1420074273
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Jim-168",
#     "link": "https://stackoverflow.com/users/4289580/jim-168",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/bde24a24bef6abb18cadd909ad5a673b?s=128&d=identicon&r=PG&f=1",
#     "reputation": 6,
#     "accept_rate": 25,
#     "user_id": 4289580
#    },
#    "tags": [
#     "php",
#     "apache",
#     ".htaccess",
#     "mod-rewrite",
#     "path"
#    ],
#    "creation_date": 1420071868,
#    "view_count": 139,
#    "question_id": 27727484,
#    "last_edit_date": 1420086773,
#    "title": "Mod-rewrite rules to manipulate query string",
#    "link": "https://stackoverflow.com/questions/27727484/mod-rewrite-rules-to-manipulate-query-string",
#    "score": 0,
#    "last_activity_date": 1420089798
#   },
#   {
#    "is_answered": true,
#    "creation_date": 1420071907,
#    "closed_reason": "off-topic",
#    "owner": {
#     "display_name": "davidawad",
#     "link": "https://stackoverflow.com/users/2178438/davidawad",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/aT0em.jpg?s=128&g=1",
#     "reputation": 336,
#     "accept_rate": 56,
#     "user_id": 2178438
#    },
#    "link": "https://stackoverflow.com/questions/27727486/file-upload-in-flask",
#    "answer_count": 1,
#    "accepted_answer_id": 27733354,
#    "view_count": 714,
#    "question_id": 27727486,
#    "closed_date": 1420182510,
#    "tags": [
#     "python",
#     "mongodb",
#     "file",
#     "io",
#     "flask"
#    ],
#    "score": 0,
#    "last_activity_date": 1420136330,
#    "title": "File Upload in Flask"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27732881,
#    "owner": {
#     "display_name": "Dd.",
#     "link": "https://stackoverflow.com/users/4081272/dd",
#     "user_type": "registered",
#     "profile_image": "https://graph.facebook.com/661410128/picture?type=large",
#     "reputation": 13,
#     "accept_rate": 50,
#     "user_id": 4081272
#    },
#    "link": "https://stackoverflow.com/questions/27727488/simple-jquery-calculation",
#    "answer_count": 2,
#    "creation_date": 1420071929,
#    "view_count": 123,
#    "question_id": 27727488,
#    "last_edit_date": 1420072751,
#    "title": "simple jquery calculation",
#    "tags": [
#     "jquery",
#     "if-statement",
#     "jquery-calculation"
#    ],
#    "score": 1,
#    "last_activity_date": 1420132551
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727704,
#    "owner": {
#     "display_name": "Tyler James Turton",
#     "link": "https://stackoverflow.com/users/4409396/tyler-james-turton",
#     "user_type": "registered",
#     "profile_image": "https://graph.facebook.com/100006346412625/picture?type=large",
#     "reputation": 3,
#     "user_id": 4409396
#    },
#    "link": "https://stackoverflow.com/questions/27727489/javascript-not-working-in-php-on-xampp",
#    "answer_count": 2,
#    "creation_date": 1420071939,
#    "view_count": 399,
#    "question_id": 27727489,
#    "last_edit_date": 1420072053,
#    "title": "Javascript not working in PHP on XAMPP",
#    "tags": [
#     "javascript",
#     "php",
#     "xampp"
#    ],
#    "score": 0,
#    "last_activity_date": 1420075691
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "crankshaft",
#     "link": "https://stackoverflow.com/users/588504/crankshaft",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/8pqMZ.png?s=128&g=1",
#     "reputation": 872,
#     "accept_rate": 41,
#     "user_id": 588504
#    },
#    "tags": [
#     "excel",
#     "vba",
#     "excel-vba",
#     "mac-office"
#    ],
#    "creation_date": 1420072002,
#    "view_count": 453,
#    "question_id": 27727491,
#    "last_edit_date": 1420072288,
#    "title": "Excel MAC VBA Dropdown",
#    "link": "https://stackoverflow.com/questions/27727491/excel-mac-vba-dropdown",
#    "score": 0,
#    "last_activity_date": 1421090378
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Cameron",
#     "link": "https://stackoverflow.com/users/333614/cameron",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/6e9714366ef2e62e8b9964bbb0100193?s=128&d=identicon&r=PG",
#     "reputation": 805,
#     "accept_rate": 50,
#     "user_id": 333614
#    },
#    "link": "https://stackoverflow.com/questions/27727493/css-solution-to-make-parent-invisible-when-all-children-are-invisible",
#    "tags": [
#     "html",
#     "css"
#    ],
#    "creation_date": 1420072021,
#    "score": 0,
#    "last_activity_date": 1420078164,
#    "view_count": 161,
#    "question_id": 27727493,
#    "title": "CSS solution to make parent invisible when all children are invisible"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27729875,
#    "owner": {
#     "display_name": "user3864563",
#     "link": "https://stackoverflow.com/users/3864563/user3864563",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/42e13fd8a963ff46905794b6ac1927cb?s=128&d=identicon&r=PG&f=1",
#     "reputation": 132,
#     "accept_rate": 71,
#     "user_id": 3864563
#    },
#    "link": "https://stackoverflow.com/questions/27727495/prevent-reset-of-currenttime-when-video-loads",
#    "answer_count": 1,
#    "creation_date": 1420072074,
#    "view_count": 339,
#    "question_id": 27727495,
#    "title": "Prevent reset of currentTime when video loads?",
#    "tags": [
#     "javascript",
#     "html5",
#     "video"
#    ],
#    "score": 0,
#    "last_activity_date": 1420107318
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "gabfiocchi",
#     "link": "https://stackoverflow.com/users/4040099/gabfiocchi",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/8334427f7a53e40c7a0af3ee91ae160b?s=128&d=identicon&r=PG&f=1",
#     "reputation": 14,
#     "user_id": 4040099
#    },
#    "link": "https://stackoverflow.com/questions/27727498/when-i-pull-to-refresh-how-i-clean-the-cache-with-ionic-framework-and-angula",
#    "tags": [
#     "javascript",
#     "json",
#     "angularjs",
#     "cordova",
#     "ionic-framework"
#    ],
#    "creation_date": 1420072129,
#    "score": 1,
#    "last_activity_date": 1420124113,
#    "view_count": 801,
#    "question_id": 27727498,
#    "title": "When I \u201cPull to refresh\u201d, How I clean the Cache? With Ionic Framework and AngularJS"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727531,
#    "owner": {
#     "display_name": "lostrva",
#     "link": "https://stackoverflow.com/users/4409397/lostrva",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/3c653dc2b09c6a3a3fdbbf401ff8d8b2?s=128&d=identicon&r=PG&f=1",
#     "reputation": 8,
#     "user_id": 4409397
#    },
#    "link": "https://stackoverflow.com/questions/27727503/properly-formatting-nstimer-in-swift",
#    "answer_count": 1,
#    "creation_date": 1420072243,
#    "view_count": 552,
#    "question_id": 27727503,
#    "last_edit_date": 1420138809,
#    "title": "Properly formatting NSTimer in Swift",
#    "tags": [
#     "swift",
#     "string-formatting"
#    ],
#    "score": 0,
#    "last_activity_date": 1420139873
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727990,
#    "owner": {
#     "display_name": "404NameNotFound",
#     "link": "https://stackoverflow.com/users/3674884/404namenotfound",
#     "user_type": "registered",
#     "profile_image": "https://graph.facebook.com/100002211124389/picture?type=large",
#     "reputation": 3,
#     "user_id": 3674884
#    },
#    "link": "https://stackoverflow.com/questions/27727509/using-as-string-parameter-on-windows-bat-files",
#    "answer_count": 1,
#    "creation_date": 1420072342,
#    "view_count": 552,
#    "question_id": 27727509,
#    "title": "Using %* as string parameter on windows .bat files",
#    "tags": [
#     "batch-file",
#     "parameters",
#     "command-prompt"
#    ],
#    "score": 0,
#    "last_activity_date": 1420081060
#   },
#   {
#    "is_answered": true,
#    "answer_count": 2,
#    "owner": {
#     "display_name": "Michael Bullock",
#     "link": "https://stackoverflow.com/users/4409383/michael-bullock",
#     "user_type": "registered",
#     "profile_image": "https://lh5.googleusercontent.com/-vSgiDPaBqco/AAAAAAAAAAI/AAAAAAAAAag/XldJ89iEr6E/photo.jpg?sz=128",
#     "reputation": 6,
#     "user_id": 4409383
#    },
#    "tags": [
#     "arrays",
#     "string",
#     "bash",
#     "variables",
#     "wget"
#    ],
#    "creation_date": 1420072354,
#    "view_count": 74,
#    "question_id": 27727513,
#    "last_edit_date": 1420077084,
#    "title": "Take parts of a string and create separate variables in bash",
#    "link": "https://stackoverflow.com/questions/27727513/take-parts-of-a-string-and-create-separate-variables-in-bash",
#    "score": 1,
#    "last_activity_date": 1420095065
#   },
#   {
#    "is_answered": false,
#    "answer_count": 3,
#    "owner": {
#     "display_name": "SamG",
#     "link": "https://stackoverflow.com/users/3950870/samg",
#     "user_type": "registered",
#     "profile_image": "https://graph.facebook.com/699601731/picture?type=large",
#     "reputation": 343,
#     "accept_rate": 88,
#     "user_id": 3950870
#    },
#    "link": "https://stackoverflow.com/questions/27727514/does-converting-this-objective-c-code-from-a-parse-tutorial-into-swift-equate-to",
#    "tags": [
#     "ios",
#     "objective-c",
#     "swift",
#     "parse.com"
#    ],
#    "creation_date": 1420072397,
#    "score": 1,
#    "last_activity_date": 1440706093,
#    "view_count": 133,
#    "question_id": 27727514,
#    "title": "Does converting this Objective-C code from a Parse tutorial into Swift equate to the same check"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27728252,
#    "owner": {
#     "display_name": "Kush Patel",
#     "link": "https://stackoverflow.com/users/4293104/kush-patel",
#     "user_type": "registered",
#     "profile_image": "https://lh4.googleusercontent.com/-pAK4NaXg6qk/AAAAAAAAAAI/AAAAAAAAABI/vUfJRf5adqI/photo.jpg?sz=128",
#     "reputation": 8,
#     "accept_rate": 50,
#     "user_id": 4293104
#    },
#    "link": "https://stackoverflow.com/questions/27727516/xcode-ios-simulator-iphone-6-and-6-plus-scaling-error",
#    "answer_count": 1,
#    "creation_date": 1420072430,
#    "view_count": 444,
#    "question_id": 27727516,
#    "title": "Xcode iOS Simulator iPhone 6 and 6 Plus Scaling Error",
#    "tags": [
#     "ios",
#     "xcode",
#     "scale"
#    ],
#    "score": -1,
#    "last_activity_date": 1420086333
#   },
#   {
#    "is_answered": false,
#    "answer_count": 0,
#    "owner": {
#     "display_name": "St0rmy",
#     "link": "https://stackoverflow.com/users/4409403/st0rmy",
#     "user_type": "registered",
#     "profile_image": "https://lh5.googleusercontent.com/-1e1GhAOAoQk/AAAAAAAAAAI/AAAAAAAAAB0/vbYjvXAak4M/photo.jpg?sz=128",
#     "reputation": 41,
#     "user_id": 4409403
#    },
#    "tags": [
#     "c#",
#     "python",
#     "logging"
#    ],
#    "creation_date": 1420072455,
#    "view_count": 95,
#    "question_id": 27727520,
#    "last_edit_date": 1420139415,
#    "title": "C# - Get Python logging stream",
#    "link": "https://stackoverflow.com/questions/27727520/c-get-python-logging-stream",
#    "score": 1,
#    "last_activity_date": 1420205868
#   },
#   {
#    "is_answered": true,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Dinoo",
#     "link": "https://stackoverflow.com/users/139644/dinoo",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/bc38599c98869fa40887fa34b57edfbf?s=128&d=identicon&r=PG",
#     "reputation": 594,
#     "accept_rate": 77,
#     "user_id": 139644
#    },
#    "tags": [
#     "java",
#     "authentication",
#     "single-sign-on",
#     "cas"
#    ],
#    "creation_date": 1420072481,
#    "view_count": 3838,
#    "question_id": 27727522,
#    "last_edit_date": 1420234403,
#    "title": "Setting up CAS Jasig Server with database authentication",
#    "link": "https://stackoverflow.com/questions/27727522/setting-up-cas-jasig-server-with-database-authentication",
#    "score": 2,
#    "last_activity_date": 1420234403
#   },
#   {
#    "is_answered": true,
#    "answer_count": 2,
#    "owner": {
#     "display_name": "benstpierre",
#     "link": "https://stackoverflow.com/users/97901/benstpierre",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/EUdyw.jpg?s=128&g=1",
#     "reputation": 12721,
#     "accept_rate": 63,
#     "user_id": 97901
#    },
#    "tags": [
#     "ios",
#     "xcode",
#     "appcode"
#    ],
#    "creation_date": 1420072610,
#    "view_count": 2978,
#    "question_id": 27727528,
#    "last_edit_date": 1434975158,
#    "title": "Appcode will not run an App that has no developer certificate",
#    "link": "https://stackoverflow.com/questions/27727528/appcode-will-not-run-an-app-that-has-no-developer-certificate",
#    "score": 12,
#    "last_activity_date": 1434975158
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27753282,
#    "owner": {
#     "display_name": "Jerry Dodge",
#     "link": "https://stackoverflow.com/users/988445/jerry-dodge",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/3386452e85998665dc0f1dd0ec2f064b?s=128&d=identicon&r=PG",
#     "reputation": 13840,
#     "accept_rate": 95,
#     "user_id": 988445
#    },
#    "link": "https://stackoverflow.com/questions/27727530/receiving-sigsegv-11-errors-in-many-places",
#    "answer_count": 1,
#    "creation_date": 1420072638,
#    "view_count": 567,
#    "question_id": 27727530,
#    "last_edit_date": 1420130680,
#    "title": "Receiving SIGSEGV (11) errors in many places",
#    "tags": [
#     "delphi",
#     "firemonkey",
#     "sigsegv",
#     "delphi-xe7"
#    ],
#    "score": 0,
#    "last_activity_date": 1420284944
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727686,
#    "owner": {
#     "display_name": "user3185748",
#     "link": "https://stackoverflow.com/users/3185748/user3185748",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/7cd3927c751a0ef5fc8105e4a3868971?s=128&d=identicon&r=PG&f=1",
#     "reputation": 1100,
#     "accept_rate": 68,
#     "user_id": 3185748
#    },
#    "link": "https://stackoverflow.com/questions/27727532/how-to-pause-code-for-animation",
#    "answer_count": 1,
#    "creation_date": 1420072667,
#    "view_count": 106,
#    "question_id": 27727532,
#    "last_edit_date": 1420220087,
#    "title": "How to pause code for animation?",
#    "tags": [
#     "ios",
#     "google-maps",
#     "animation",
#     "swift",
#     "screenshot"
#    ],
#    "score": 0,
#    "last_activity_date": 1420220087
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27759098,
#    "owner": {
#     "display_name": "Gage Ervin",
#     "link": "https://stackoverflow.com/users/3732350/gage-ervin",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/ohFi4.jpg?s=128&g=1",
#     "reputation": 70,
#     "accept_rate": 50,
#     "user_id": 3732350
#    },
#    "link": "https://stackoverflow.com/questions/27727533/qt-cannot-instantiate-an-object-in-a-windows-constructor",
#    "answer_count": 1,
#    "creation_date": 1420072685,
#    "view_count": 637,
#    "question_id": 27727533,
#    "last_edit_date": 1420148884,
#    "title": "Qt, cannot instantiate an object in a window&#39;s constructor?",
#    "tags": [
#     "c++",
#     "qt"
#    ],
#    "score": 1,
#    "last_activity_date": 1420316137
#   },
#   {
#    "is_answered": false,
#    "answer_count": 0,
#    "owner": {
#     "display_name": "\u0410\u043d\u0434\u0440\u0435\u0439 \u0418\u0432\u0430\u043d\u043e\u0432",
#     "link": "https://stackoverflow.com/users/4409404/%d0%90%d0%bd%d0%b4%d1%80%d0%b5%d0%b9-%d0%98%d0%b2%d0%b0%d0%bd%d0%be%d0%b2",
#     "user_type": "registered",
#     "profile_image": "https://graph.facebook.com/100005879591844/picture?type=large",
#     "reputation": 1,
#     "user_id": 4409404
#    },
#    "tags": [
#     "objective-c",
#     "parse.com",
#     "push-notification"
#    ],
#    "creation_date": 1420072777,
#    "view_count": 305,
#    "question_id": 27727535,
#    "last_edit_date": 1420283727,
#    "title": "Parse push notification with iOS",
#    "link": "https://stackoverflow.com/questions/27727535/parse-push-notification-with-ios",
#    "score": 0,
#    "last_activity_date": 1420283727
#   },
#   {
#    "is_answered": true,
#    "answer_count": 2,
#    "owner": {
#     "display_name": "Rakesh Vasu",
#     "link": "https://stackoverflow.com/users/1839812/rakesh-vasu",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/900185114b8c842cd759ad37b2801eb6?s=128&d=identicon&r=PG",
#     "reputation": 35,
#     "accept_rate": 40,
#     "user_id": 1839812
#    },
#    "tags": [
#     "sql",
#     "dense-rank"
#    ],
#    "creation_date": 1420072779,
#    "view_count": 128,
#    "question_id": 27727536,
#    "last_edit_date": 1420077393,
#    "title": "Sql ranking groups based on a values in a field",
#    "link": "https://stackoverflow.com/questions/27727536/sql-ranking-groups-based-on-a-values-in-a-field",
#    "score": 2,
#    "last_activity_date": 1420088972
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727579,
#    "owner": {
#     "display_name": "John",
#     "link": "https://stackoverflow.com/users/2670571/john",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/0c4a608118770c1bdfbc1ad857a375bf?s=128&d=identicon&r=PG",
#     "reputation": 991,
#     "accept_rate": 52,
#     "user_id": 2670571
#    },
#    "link": "https://stackoverflow.com/questions/27727546/what-to-use-instead-of-xmlbeans-now-that-it-has-been-retired",
#    "answer_count": 1,
#    "creation_date": 1420072902,
#    "view_count": 11957,
#    "question_id": 27727546,
#    "last_edit_date": 1473420860,
#    "title": "What to use instead of XMLBeans now that it has been retired?",
#    "tags": [
#     "java",
#     "xml",
#     "xsd",
#     "xmlbeans"
#    ],
#    "score": 17,
#    "last_activity_date": 1473420860
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727650,
#    "owner": {
#     "display_name": "Sopalajo de Arrierez",
#     "link": "https://stackoverflow.com/users/1461017/sopalajo-de-arrierez",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/W3CrL.jpg?s=128&g=1",
#     "reputation": 1068,
#     "accept_rate": 27,
#     "user_id": 1461017
#    },
#    "link": "https://stackoverflow.com/questions/27727550/linux-shell-adding-dots-to-numerical-outputs-to-make-them-more-readable",
#    "answer_count": 1,
#    "creation_date": 1420072924,
#    "view_count": 347,
#    "question_id": 27727550,
#    "last_edit_date": 1420073516,
#    "title": "Linux shell: Adding dots to numerical outputs to make them more readable",
#    "tags": [
#     "linux",
#     "bash",
#     "numbers"
#    ],
#    "score": 3,
#    "last_activity_date": 1420089378
#   },
#   {
#    "is_answered": false,
#    "answer_count": 0,
#    "owner": {
#     "display_name": "Steve",
#     "link": "https://stackoverflow.com/users/237908/steve",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/822419cf6f335b1c1564a2bc37e0f4db?s=128&d=identicon&r=PG",
#     "reputation": 1203,
#     "accept_rate": 50,
#     "user_id": 237908
#    },
#    "link": "https://stackoverflow.com/questions/27727553/aging-strategy-described-in-the-elasticsearch-websites-retiring-data-document",
#    "tags": [
#     "optimization",
#     "elasticsearch",
#     "cluster-computing",
#     "logstash",
#     "kibana"
#    ],
#    "creation_date": 1420072976,
#    "score": 1,
#    "last_activity_date": 1420072976,
#    "view_count": 828,
#    "question_id": 27727553,
#    "title": "Aging strategy described in the ElasticSearch website&#39;s &quot;Retiring Data&quot; document isn&#39;t working for me"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 32256443,
#    "owner": {
#     "display_name": "Abundance",
#     "link": "https://stackoverflow.com/users/3052463/abundance",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/3w2GR.jpg?s=128&g=1",
#     "reputation": 449,
#     "accept_rate": 78,
#     "user_id": 3052463
#    },
#    "link": "https://stackoverflow.com/questions/27727554/ollydbg-and-dumpbin-do-not-give-same-disassembly",
#    "answer_count": 1,
#    "creation_date": 1420072979,
#    "view_count": 157,
#    "question_id": 27727554,
#    "title": "OllyDBG and Dumpbin do not give same disassembly",
#    "tags": [
#     "ollydbg",
#     "dumpbin",
#     "ntdll"
#    ],
#    "score": 1,
#    "last_activity_date": 1463675202
#   },
#   {
#    "is_answered": true,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "norbertpy",
#     "link": "https://stackoverflow.com/users/4228942/norbertpy",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/2rplF.jpg?s=128&g=1",
#     "reputation": 1571,
#     "accept_rate": 85,
#     "user_id": 4228942
#    },
#    "tags": [
#     "error-handling",
#     "django-rest-framework"
#    ],
#    "creation_date": 1420072997,
#    "view_count": 2875,
#    "question_id": 27727556,
#    "last_edit_date": 1420081182,
#    "title": "django-rest-framework custom error message as response",
#    "link": "https://stackoverflow.com/questions/27727556/django-rest-framework-custom-error-message-as-response",
#    "score": 2,
#    "last_activity_date": 1420081449
#   },
#   {
#    "is_answered": false,
#    "answer_count": 2,
#    "owner": {
#     "display_name": "Janek",
#     "link": "https://stackoverflow.com/users/3448171/janek",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/0e065233060ab6f87d2408f5008e0a89?s=128&d=identicon&r=PG&f=1",
#     "reputation": 2,
#     "accept_rate": 0,
#     "user_id": 3448171
#    },
#    "tags": [
#     "javascript",
#     "php",
#     "login"
#    ],
#    "creation_date": 1420073055,
#    "view_count": 108,
#    "question_id": 27727560,
#    "last_edit_date": 1420080566,
#    "title": "Login script in javascript failed",
#    "link": "https://stackoverflow.com/questions/27727560/login-script-in-javascript-failed",
#    "score": 1,
#    "last_activity_date": 1420099576
#   },
#   {
#    "is_answered": true,
#    "creation_date": 1420073169,
#    "closed_reason": "too broad",
#    "owner": {
#     "display_name": "John",
#     "link": "https://stackoverflow.com/users/4409419/john",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/b7e651dcbdaa0777c6c4762f57068e25?s=128&d=identicon&r=PG&f=1",
#     "reputation": 18,
#     "user_id": 4409419
#    },
#    "link": "https://stackoverflow.com/questions/27727564/how-do-i-embed-a-batch-file-in-a-vb-program",
#    "answer_count": 1,
#    "accepted_answer_id": 27727588,
#    "view_count": 132,
#    "question_id": 27727564,
#    "last_edit_date": 1420074752,
#    "closed_date": 1420073836,
#    "tags": [
#     "vb.net"
#    ],
#    "score": -3,
#    "last_activity_date": 1420074752,
#    "title": "How do I embed a batch file in a vb program?"
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Indian",
#     "link": "https://stackoverflow.com/users/2397634/indian",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/2575f23b758e9141865a0dc6731bb44f?s=128&d=identicon&r=PG",
#     "reputation": 277,
#     "accept_rate": 45,
#     "user_id": 2397634
#    },
#    "link": "https://stackoverflow.com/questions/27727571/plotting-r-legend-positioning-units-font",
#    "tags": [
#     "r",
#     "graph"
#    ],
#    "creation_date": 1420073273,
#    "score": 0,
#    "last_activity_date": 1420074684,
#    "view_count": 86,
#    "question_id": 27727571,
#    "title": "Plotting: R: Legend positioning (units) + font"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 28069917,
#    "owner": {
#     "display_name": "corvid",
#     "link": "https://stackoverflow.com/users/1150599/corvid",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/ndWQ0.jpg?s=128&g=1",
#     "reputation": 4594,
#     "accept_rate": 48,
#     "user_id": 1150599
#    },
#    "link": "https://stackoverflow.com/questions/27727572/gettrackedachievements-returning-number-rather-than-list",
#    "answer_count": 2,
#    "creation_date": 1420073276,
#    "view_count": 63,
#    "question_id": 27727572,
#    "title": "GetTrackedAchievements returning number rather than list",
#    "tags": [
#     "lua",
#     "world-of-warcraft"
#    ],
#    "score": 2,
#    "last_activity_date": 1421852318
#   },
#   {
#    "is_answered": true,
#    "answer_count": 2,
#    "owner": {
#     "display_name": "Kevin Meredith",
#     "link": "https://stackoverflow.com/users/409976/kevin-meredith",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/9ccda0b49cc974197399eae01ebd6850?s=128&d=identicon&r=PG",
#     "reputation": 14277,
#     "accept_rate": 68,
#     "user_id": 409976
#    },
#    "link": "https://stackoverflow.com/questions/27727575/reader-applicatives-apply-function",
#    "tags": [
#     "haskell"
#    ],
#    "creation_date": 1420073352,
#    "score": 4,
#    "last_activity_date": 1420214730,
#    "view_count": 147,
#    "question_id": 27727575,
#    "title": "Reader Applicative&#39;s Apply Function"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727600,
#    "owner": {
#     "display_name": "user3658885",
#     "link": "https://stackoverflow.com/users/3658885/user3658885",
#     "user_type": "registered",
#     "profile_image": "https://graph.facebook.com/100008325033686/picture?type=large",
#     "reputation": 3,
#     "accept_rate": 75,
#     "user_id": 3658885
#    },
# ...
#     "wpf",
#     "listview"
#    ],
#    "score": 0,
#    "last_activity_date": 1420075510
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27729614,
#    "owner": {
#     "display_name": "beth",
#     "link": "https://stackoverflow.com/users/1370106/beth",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/ca34e049a3e40e10f2cf7a13825bbc3e?s=128&d=identicon&r=PG",
#     "reputation": 743,
#     "accept_rate": 82,
#     "user_id": 1370106
#    },
#    "link": "https://stackoverflow.com/questions/27727629/accessing-a-service-inside-an-event-subscriber",
#    "answer_count": 1,
#    "creation_date": 1420074356,
#    "view_count": 1792,
#    "question_id": 27727629,
#    "title": "Accessing a service inside an event subscriber",
#    "tags": [
#     "symfony",
#     "dependency-injection",
#     "lifecycle"
#    ],
#    "score": 2,
#    "last_activity_date": 1420104414
#   },
#   {
#    "is_answered": true,
#    "answer_count": 2,
#    "owner": {
#     "display_name": "Carlos Liam",
#     "link": "https://stackoverflow.com/users/4270716/carlos-liam",
#     "user_type": "registered",
#     "profile_image": "https://lh3.googleusercontent.com/-m-qNRAIhRAk/AAAAAAAAAAI/AAAAAAAAAD4/jz1TKqIM9f0/photo.jpg?sz=128",
#     "reputation": 70,
#     "accept_rate": 33,
#     "user_id": 4270716
#    },
#    "link": "https://stackoverflow.com/questions/27727631/issue-with-horizontal-css-transformation-transformation-being-multiplied",
#    "tags": [
#     "css",
#     "css3",
#     "transform"
#    ],
#    "creation_date": 1420074436,
#    "score": 1,
#    "last_activity_date": 1420113320,
#    "view_count": 41,
#    "question_id": 27727631,
#    "title": "Issue with horizontal CSS transformation (transformation being multiplied?)"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727667,
#    "owner": {
#     "display_name": "bbetnar",
#     "link": "https://stackoverflow.com/users/4409425/bbetnar",
#     "user_type": "registered",
#     "profile_image": "https://lh5.googleusercontent.com/-edyyNU1emMs/AAAAAAAAAAI/AAAAAAAAByQ/W7FesMDequ4/photo.jpg?sz=128",
#     "reputation": 22,
#     "user_id": 4409425
#    },
#    "link": "https://stackoverflow.com/questions/27727635/insert-vba-sub-into-excel-worksheet",
#    "answer_count": 1,
#    "creation_date": 1420074492,
#    "view_count": 495,
#    "question_id": 27727635,
#    "last_edit_date": 1420099503,
#    "title": "Insert VBA sub into Excel Worksheet",
#    "tags": [
#     "excel",
#     "excel-vba"
#    ],
#    "score": 2,
#    "last_activity_date": 1420099503
#   },
#   {
#    "is_answered": true,
#    "creation_date": 1420074515,
#    "closed_reason": "duplicate",
#    "owner": {
#     "display_name": "KnowItAllWannabe",
#     "link": "https://stackoverflow.com/users/1426649/knowitallwannabe",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/b8f3e3968428bd663aea584352bc556c?s=128&d=identicon&r=PG",
#     "reputation": 4526,
#     "accept_rate": 57,
#     "user_id": 1426649
#    },
#    "link": "https://stackoverflow.com/questions/27727637/why-does-the-const-in-a-const-t-parameter-disappear-when-t-is-a-reference-type",
#    "answer_count": 2,
#    "view_count": 299,
#    "question_id": 27727637,
#    "closed_date": 1420084804,
#    "tags": [
#     "c++",
#     "templates",
#     "type-deduction"
#    ],
#    "score": 4,
#    "last_activity_date": 1420081693,
#    "title": "Why does the const in a const T&amp; parameter disappear when T is a reference type?"
#   },
#   {
#    "is_answered": true,
#    "answer_count": 3,
#    "owner": {
#     "display_name": "Sopalajo de Arrierez",
#     "link": "https://stackoverflow.com/users/1461017/sopalajo-de-arrierez",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/W3CrL.jpg?s=128&g=1",
#     "reputation": 1068,
#     "accept_rate": 27,
#     "user_id": 1461017
#    },
#    "tags": [
#     "linux",
#     "shell",
#     "numbers"
#    ],
#    "creation_date": 1420074596,
#    "view_count": 151,
#    "question_id": 27727641,
#    "last_edit_date": 1495542743,
#    "title": "Linux shell scripting: How can I remove initial numbers in a word list file?",
#    "link": "https://stackoverflow.com/questions/27727641/linux-shell-scripting-how-can-i-remove-initial-numbers-in-a-word-list-file",
#    "score": 0,
#    "last_activity_date": 1420200155
#   },
#   {
#    "is_answered": false,
#    "answer_count": 0,
#    "owner": {
#     "display_name": "Jim C",
#     "link": "https://stackoverflow.com/users/4148175/jim-c",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/5292692b48cc43a28b55d8fd6581bbed?s=128&d=identicon&r=PG&f=1",
#     "reputation": 422,
#     "accept_rate": 60,
#     "user_id": 4148175
#    },
#    "tags": [
#     "spring",
#     "spring-mvc",
#     "dependency-injection",
#     "scope",
#     "resttemplate"
#    ],
#    "creation_date": 1420074602,
#    "view_count": 818,
#    "question_id": 27727642,
#    "last_edit_date": 1495542034,
#    "title": "why autowired variable in prototype scope works only in the first instance",
#    "link": "https://stackoverflow.com/questions/27727642/why-autowired-variable-in-prototype-scope-works-only-in-the-first-instance",
#    "score": 0,
#    "last_activity_date": 1420206810
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "Durga Dutt",
#     "link": "https://stackoverflow.com/users/553739/durga-dutt",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/59bba2449a6f9439ae1d51e655801671?s=128&d=identicon&r=PG",
#     "reputation": 1618,
#     "accept_rate": 56,
#     "user_id": 553739
#    },
#    "link": "https://stackoverflow.com/questions/27727643/server-ssl-incomplete-chain-inmotion-server",
#    "tags": [
#     "ssl"
#    ],
#    "creation_date": 1420074640,
#    "score": 0,
#    "last_activity_date": 1421640099,
#    "view_count": 189,
#    "question_id": 27727643,
#    "title": "Server SSL incomplete chain (Inmotion server)"
#   },
#   {
#    "is_answered": false,
#    "answer_count": 0,
#    "owner": {
#     "display_name": "user1091524",
#     "link": "https://stackoverflow.com/users/1091524/user1091524",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/3493891e2e1ea01f03239c7e2aeafc25?s=128&d=identicon&r=PG",
#     "reputation": 405,
#     "accept_rate": 23,
#     "user_id": 1091524
#    },
#    "tags": [
#     "android",
#     "listview",
#     "checkbox"
#    ],
#    "creation_date": 1420074817,
#    "view_count": 89,
#    "question_id": 27727654,
#    "last_edit_date": 1420153188,
#    "title": "Listview and checkboxes - setting, checking, getting checked",
#    "link": "https://stackoverflow.com/questions/27727654/listview-and-checkboxes-setting-checking-getting-checked",
#    "score": 0,
#    "last_activity_date": 1420153188
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27730724,
#    "owner": {
#     "display_name": "tasaduq",
#     "link": "https://stackoverflow.com/users/4409426/tasaduq",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/dd3c0e8fdaa828098c7f0238081774b3?s=128&d=identicon&r=PG&f=1",
#     "reputation": 71,
#     "user_id": 4409426
#    },
#    "link": "https://stackoverflow.com/questions/27727655/can-not-populate-bootstrap-select-with-data-live-search-multiple-with-jquery",
#    "answer_count": 1,
#    "creation_date": 1420074822,
#    "view_count": 6852,
#    "question_id": 27727655,
#    "last_edit_date": 1420113839,
#    "title": "Can not populate bootstrap select with data live search + multiple with jquery",
#    "tags": [
#     "javascript",
#     "jquery",
#     "twitter-bootstrap",
#     "multi-select",
#     "livesearch"
#    ],
#    "score": 1,
#    "last_activity_date": 1420114580
#   },
#   {
#    "is_answered": false,
#    "answer_count": 2,
#    "owner": {
#     "display_name": "se7en",
#     "link": "https://stackoverflow.com/users/4409431/se7en",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/a550c8e8e415d8549fd9c088859e1495?s=128&d=identicon&r=PG&f=1",
#     "reputation": 7,
#     "accept_rate": 17,
#     "user_id": 4409431
#    },
#    "tags": [
#     "php",
#     "arrays",
#     "json"
#    ],
#    "creation_date": 1420074825,
#    "view_count": 59,
#    "question_id": 27727656,
#    "last_edit_date": 1420076135,
#    "title": "PHP+JSON Display result with no key?",
#    "link": "https://stackoverflow.com/questions/27727656/phpjson-display-result-with-no-key",
#    "score": 0,
#    "last_activity_date": 1420076586
#   },
#   {
#    "is_answered": true,
#    "creation_date": 1420074859,
#    "closed_reason": "too broad",
#    "owner": {
#     "display_name": "DANIEL REAPSOME",
#     "link": "https://stackoverflow.com/users/4409432/daniel-reapsome",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/9405ddc47d0b2d0821e92a1693c355cd?s=128&d=identicon&r=PG&f=1",
#     "reputation": 20,
#     "user_id": 4409432
#    },
#    "link": "https://stackoverflow.com/questions/27727657/parsing-html-information-with-beautifulsoup4-in-python",
#    "answer_count": 1,
#    "accepted_answer_id": 27729078,
#    "view_count": 42,
#    "question_id": 27727657,
#    "closed_date": 1421180028,
#    "tags": [
#     "python",
#     "html",
#     "parsing"
#    ],
#    "score": -3,
#    "last_activity_date": 1420097599,
#    "title": "parsing html information with beautifulsoup4 in python"
#   },
#   {
#    "is_answered": false,
#    "answer_count": 1,
#    "owner": {
#     "display_name": "fuuman",
#     "link": "https://stackoverflow.com/users/3420062/fuuman",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/bFXmB.png?s=128&g=1",
#     "reputation": 142,
#     "accept_rate": 83,
#     "user_id": 3420062
#    },
#    "link": "https://stackoverflow.com/questions/27727664/navigationbar-totally-left",
#    "tags": [
#     "html",
#     "css"
#    ],
#    "creation_date": 1420075017,
#    "score": 0,
#    "last_activity_date": 1420076354,
#    "view_count": 23,
#    "question_id": 27727664,
#    "title": "Navigationbar totally left"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727884,
#    "owner": {
#     "display_name": "GiannisIordanou",
#     "link": "https://stackoverflow.com/users/896317/giannisiordanou",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/ms0k9.jpg?s=128&g=1",
#     "reputation": 743,
#     "accept_rate": 50,
#     "user_id": 896317
#    },
#    "link": "https://stackoverflow.com/questions/27727666/how-can-i-split-a-list-of-lists-based-on-a-specific-condition-in-python",
#    "answer_count": 4,
#    "creation_date": 1420075026,
#    "view_count": 97,
#    "question_id": 27727666,
#    "title": "How can I split a list of lists based on a specific condition in Python?",
#    "tags": [
#     "python",
#     "list"
#    ],
#    "score": 3,
#    "last_activity_date": 1420082558
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727700,
#    "owner": {
#     "display_name": "Fluxcapacitor",
#     "link": "https://stackoverflow.com/users/1906526/fluxcapacitor",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/1i2Bf.jpg?s=128&g=1",
#     "reputation": 121,
#     "accept_rate": 31,
#     "user_id": 1906526
#    },
#    "link": "https://stackoverflow.com/questions/27727668/why-does-p-element-jump-out-of-div-and-appear-in-next-line-below",
#    "answer_count": 1,
#    "creation_date": 1420075038,
#    "view_count": 76,
#    "question_id": 27727668,
#    "title": "Why does &lt;p&gt; element jump out of div and appear in next line below?",
#    "tags": [
#     "html",
#     "css"
#    ],
#    "score": 0,
#    "last_activity_date": 1420075585
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27748558,
#    "owner": {
#     "display_name": "lazypig",
#     "link": "https://stackoverflow.com/users/1804667/lazypig",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/56890ef4338c7a35afd2bacf362874e1?s=128&d=identicon&r=PG",
#     "reputation": 387,
#     "accept_rate": 33,
#     "user_id": 1804667
#    },
#    "link": "https://stackoverflow.com/questions/27727670/android-robolectric-gradle-java-lang-outofmemoryerror-permgen-space",
#    "answer_count": 2,
#    "creation_date": 1420075056,
#    "view_count": 4105,
#    "question_id": 27727670,
#    "last_edit_date": 1495541687,
#    "title": "Android Robolectric Gradle - java.lang.OutOfMemoryError: PermGen space",
#    "tags": [
#     "android",
#     "gradle",
#     "out-of-memory",
#     "robolectric"
#    ],
#    "score": 5,
#    "last_activity_date": 1430761794
#   },
#   {
#    "is_answered": false,
#    "answer_count": 0,
#    "owner": {
#     "display_name": "michelpm",
#     "link": "https://stackoverflow.com/users/619510/michelpm",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/de1373715118caea7c80e173bd7ab04e?s=128&d=identicon&r=PG",
#     "reputation": 965,
#     "accept_rate": 92,
#     "user_id": 619510
#    },
#    "link": "https://stackoverflow.com/questions/27727671/add-map-as-drilldown-for-pie-chart",
#    "tags": [
#     "highcharts"
#    ],
#    "creation_date": 1420075078,
#    "score": 0,
#    "last_activity_date": 1420075078,
#    "view_count": 170,
#    "question_id": 27727671,
#    "title": "Add map as drilldown for pie chart"
#   },
#   {
#    "is_answered": true,
#    "creation_date": 1420075080,
#    "closed_reason": "duplicate",
#    "owner": {
#     "display_name": "Roy",
#     "link": "https://stackoverflow.com/users/3935165/roy",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/216aab2c76fcd2102e7439f001db2eec?s=128&d=identicon&r=PG&f=1",
#     "reputation": 197,
#     "accept_rate": 70,
#     "user_id": 3935165
#    },
#    "link": "https://stackoverflow.com/questions/27727672/select-columns-with-the-same-prefix",
#    "answer_count": 1,
#    "view_count": 653,
#    "question_id": 27727672,
#    "last_edit_date": 1420682670,
#    "closed_date": 1420683420,
#    "tags": [
#     "postgresql",
#     "select",
#     "plpgsql",
#     "dynamic-sql"
#    ],
#    "score": 0,
#    "last_activity_date": 1420682670,
#    "title": "Select columns with the same prefix"
#   },
#   {
#    "is_answered": false,
#    "creation_date": 1420075100,
#    "closed_reason": "duplicate",
#    "owner": {
#     "display_name": "Michael St Clair",
#     "link": "https://stackoverflow.com/users/1998220/michael-st-clair",
#     "user_type": "registered",
#     "profile_image": "https://i.stack.imgur.com/bpbf0.jpg?s=128&g=1",
#     "reputation": 732,
#     "accept_rate": 88,
#     "user_id": 1998220
#    },
#    "link": "https://stackoverflow.com/questions/27727673/return-value-of-0-from-mysql-query-if-empty",
#    "answer_count": 0,
#    "view_count": 30,
#    "question_id": 27727673,
#    "closed_date": 1420076239,
#    "tags": [
#     "mysql"
#    ],
#    "score": 2,
#    "last_activity_date": 1420076037,
#    "title": "Return value of 0 from MySQL query if empty"
#   },
#   {
#    "is_answered": true,
#    "accepted_answer_id": 27727709,
#    "owner": {
#     "display_name": "tika",
#     "link": "https://stackoverflow.com/users/2988919/tika",
#     "user_type": "registered",
#     "profile_image": "https://graph.facebook.com/100006578318645/picture?type=large",
#     "reputation": 2508,
#     "accept_rate": 93,
#     "user_id": 2988919
#    },
#    "link": "https://stackoverflow.com/questions/27727675/function-return-error-in-ios",
#    "answer_count": 1,
#    "creation_date": 1420075129,
#    "view_count": 323,
#    "question_id": 27727675,
#    "last_edit_date": 1420081077,
#    "title": "Function Return Error in iOS",
#    "tags": [
#     "ios",
#     "swift",
#     "nsmutablearray"
#    ],
#    "score": 0,
#    "last_activity_date": 1420081077
#   },
#   {
#    "is_answered": false,
#    "answer_count": 0,
#    "owner": {
#     "display_name": "Dan",
#     "link": "https://stackoverflow.com/users/2752238/dan",
#     "user_type": "registered",
#     "profile_image": "https://www.gravatar.com/avatar/2ead48456c43a72f021001549d5144d4?s=128&d=identicon&r=PG&f=1",
#     "reputation": 23,
#     "user_id": 2752238
#    },
#    "tags": [
#     "java",
#     "android",
#     "cordova",
#     "ionic-framework"
#    ],
#    "creation_date": 1420075130,
#    "view_count": 621,
#    "question_id": 27727676,
#    "last_edit_date": 1420076280,
#    "title": "Unable to instantiate receiver com.parse.GcmBroadcastReceiver",
#    "link": "https://stackoverflow.com/questions/27727676/unable-to-instantiate-receiver-com-parse-gcmbroadcastreceiver",
#    "score": 4,
#    "last_activity_date": 1420076280
#   }
#  ]
# }

# %% [markdown]
# Now we can easily see that the response consists of a list of question items. For each of these items, we get information about its attributes such as its `creation_date`, `answer_count`, `owner`, `title`, etc.
#
# Notice that has_more is true. To get more items, we can [request the next page](https://api.stackexchange.com/docs/paging).

# %% [markdown]
# -----------------

# %% [markdown]
# ## Step 2. Parsing the responses

# %% [markdown]
# In this section, we practice some of the basic Python tools that we learned in class and the powerful string handling methods that Python offers. Our goal is to be able to pick the interesting parts of the response and transform them in a format that will be useful to us.

# %% [markdown]
# First let's isolate the creation_date in the response. Fill in the rest of the ```print_creation_dates_json()``` function that reads the response and prints the creation dates and whether the question was answered. Your solution should be in the form **(creation_date,is_answered)**. Notice that a JSON object is basically a dictionary. **(5 pts)**

# %%
def print_creation_dates_is_answered_json(response):
    """
    Prints the creation_date of all the questions in the response.
    
    Parameters:
        response: Response object
    """
    
    creation_date = [item['creation_date'] for item in response.json()['items']] 
    is_answered = [item['is_answered'] for item in response.json()['items']] 
    new_response = creation_date, is_answered
    return creation_date, is_answered

creation_date, is_answered = print_creation_dates_is_answered_json(response)
for i in range(len(creation_date)):
    print((creation_date[i],is_answered[i]))
# Out:
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)

# %% [markdown]
# Write the code that calls the ```print_creation_dates_is_answered_json()``` function to print out all the creation dates of questions posted on the first day in 2015. Please be aware of Stack Exchange's [rate limit](https://api.stackexchange.com/docs/throttle). This means that after getting a request, you will need to wait for some seconds before making a new request. If you do not do that, stack exchange will block you from making any new requests. **(5 pts)**

# %%
import requests
from datetime import datetime
import time as tm


start_time = 1420070400 # 01-01-2015 at 00:00:00
end_time   = 1420156800 # 01-02-2015 at 00:00:00
hs_more = True
page_no = 1

while(hs_more):
    new_response = requests.get("https://api.stackexchange.com/2.2/questions?pagesize=100" + 
                    "&pageNo=" + str(page_no) + "&fromdate=" + str(start_time) + "&todate=" + str(end_time) +
                    "&order=asc&sort=creation&site=stackoverflow")
    
    
    n_response = new_response.json() 
    hs_more = n_response["has_more"]
    tm.sleep(2)
    page_no+=1
    print('*'*100)
    creation_date, is_answered = print_creation_dates_is_answered_json(new_response)
    for i in range(len(creation_date)):
        print((creation_date[i],is_answered[i]))
# Out:
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# ...
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ****************************************************************************************************
# (1420070458, True)
# (1420070503, False)
# (1420070552, True)
# (1420070577, True)
# (1420070611, True)
# (1420070641, False)
# (1420070703, False)
# (1420070727, True)
# (1420070734, True)
# (1420070777, False)
# (1420070801, True)
# (1420070848, True)
# (1420070859, True)
# (1420070866, False)
# (1420070968, True)
# (1420071005, False)
# (1420071029, True)
# (1420071103, True)
# (1420071122, True)
# (1420071175, True)
# (1420071184, False)
# (1420071212, False)
# (1420071230, False)
# (1420071340, True)
# (1420071431, True)
# (1420071530, True)
# (1420071736, False)
# (1420071794, True)
# (1420071830, True)
# (1420071868, False)
# (1420071907, True)
# (1420071929, True)
# (1420071939, True)
# (1420072002, False)
# (1420072021, False)
# (1420072074, True)
# (1420072129, False)
# (1420072243, True)
# (1420072342, True)
# (1420072354, True)
# (1420072397, False)
# (1420072430, True)
# (1420072455, False)
# (1420072481, True)
# (1420072610, True)
# (1420072638, True)
# (1420072667, True)
# (1420072685, True)
# (1420072777, False)
# (1420072779, True)
# (1420072902, True)
# (1420072924, True)
# (1420072976, False)
# (1420072979, True)
# (1420072997, True)
# (1420073055, False)
# (1420073169, True)
# (1420073273, False)
# (1420073276, True)
# (1420073352, True)
# (1420073383, True)
# (1420073425, False)
# (1420073455, True)
# (1420073456, True)
# (1420073492, True)
# (1420073510, True)
# (1420073524, True)
# (1420073787, False)
# (1420073851, True)
# (1420073932, True)
# (1420074037, True)
# (1420074057, False)
# (1420074085, False)
# (1420074170, False)
# (1420074204, True)
# (1420074224, False)
# (1420074226, True)
# (1420074269, False)
# (1420074320, False)
# (1420074334, True)
# (1420074356, True)
# (1420074436, True)
# (1420074492, True)
# (1420074515, True)
# (1420074596, True)
# (1420074602, False)
# (1420074640, False)
# (1420074817, False)
# (1420074822, True)
# (1420074825, False)
# (1420074859, True)
# (1420075017, False)
# (1420075026, True)
# (1420075038, True)
# (1420075056, True)
# (1420075078, False)
# (1420075080, True)
# (1420075100, False)
# (1420075129, True)
# (1420075130, False)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-30e25008b388> in <module>()
#      17     n_response = new_response.json()
#      18     #print(json.dumps(n_response, indent=1))
# ---> 19     hs_more = n_response["has_more"]
#      20     tm.sleep(2)
#      21     page_no+=1
#
# KeyError: 'has_more'

# %% [markdown]
# Due to time constraints, we have downloaded the [data dump](https://drive.google.com/a/bu.edu/file/d/0BzeSDLWpnNHxaEd5XzhIZ2tJMlU/view?usp=sharing) for Stack Overflow's posts in 2015. Note that the XML file is 10GB. If you don't have space on your computer, you can download it into `/scratch` on one of the machines in the undergrad lab or you can download it onto a USB. Your solution should work with the whole dataset.
#
# Do not commit the data file to your github. You may assume that we will place the data file in the same directory as your IPython Notebook, so provide a relative path when loading the data file.
#
# Write a function to parse out the questions and answers posted in 2015. Questions are posts with `PostTypeId=1` and answers are posts with `PostTypeId=2`. Then:
# 1. Make a `pandas DataFrame` with the following 7 columns: `Id`, `CreationDate`, `OwnerUserId`, the first tag in `Tags`, `ViewCount`, `Score`, `Type`. Note that the first 3 columns are common for both questions and answers, the following 2 are only identified in questions and the next column in answers. Finally column `Type` is used show whether the row of the data frame corresponds to a question or answer. You can assign 'Q' for question and 'A' for answer to this column. Also, if you do not have a value for a column, for instance an answer does not have a view count, then simply add None as a value.
# 2. Print out the time required to parse the questions (data file).
# 3. Print out the DataFrame.
# 4. Do not clear the output.
# **(10 pts)**
#
# Some hints/library you might find useful are the following:
# 1. One library you can use to parse the large .xml file is the `xml.etree.ElementTree` library. More documentation can be found [here](https://docs.python.org/2/library/xml.etree.elementtree.html).
# 2. Due to the required parsing time, it is strongly recommended that you write the parsed data in another file on the disk. Thus, even if something goes wrong you will always have these data to work with, which will give you partial credit.
# 3. Before traversing the whole dataset, play with a small subset first in order to construct your solution fast.

# %%
# File imports
import xml.etree.ElementTree as ET
import pandas as pd
import pandas_datareader.data as web
from pandas import Series
from pandas import DataFrame
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from datetime import datetime
import numpy as np
from collections import defaultdict

# %%
# Functions
t1 = datetime.now()

tree = open('stackoverflow-posts-2015.xml', errors = 'ignore' )

#tree = 'stackoverflow-posts-2015.xml'
questiondf = []
answerdf = [] 

for events, elem in ET.iterparse(tree, events=("start", "end")):
    question = defaultdict(dict)
    answer = defaultdict(dict)
    try: 
        if events == "start":
            if elem.attrib['PostTypeId']=='1': 
                
                question['Id'] = (elem.attrib['Id'])
                question['CreationDate']=(elem.attrib['CreationDate'])
                question['OwnerUserId']=(elem.attrib['OwnerUserId'])
                question['Tags']=(elem.attrib['Tags'].split('>')[0][1:])
                question['ViewCount']=(elem.attrib['ViewCount'])
                question['Score']= None
                question['Type']=('Q')
                questiondf.append(question)
            
            if elem.attrib['PostTypeId']=='2':
                answer['Id'] = (elem.attrib['Id'])
                answer['CreationDate']=(elem.attrib['CreationDate'])
                answer['OwnerUserId']=(elem.attrib['OwnerUserId'])
                answer['Tags']= None
                answer['ViewCount']= None
                answer['Score']=(elem.attrib['Score'])
                answer['Type']= ('A')
                questiondf.append(answer)
            
    except: None


df = DataFrame(questiondf)
df_a = DataFrame(answerdf)
print(df)
#df.to_csv('parse_data.csv')

t2 = datetime.now()
print(t2-t1)
# Out:
#                     CreationDate        Id OwnerUserId Score            Tags  \
# 0        2015-01-01T00:00:27.040  27727381     1971096     6            None
# 1        2015-01-01T00:00:31.240  27727382     2410359     0            None
# 2        2015-01-01T00:00:50.550  27727384     1366219     1            None
# 3        2015-01-01T00:00:58.253  27727385     3210431  None             php
# 4        2015-01-01T00:01:43.597  27727387     3886175     0            None
# 5        2015-01-01T00:01:43.673  27727388      868779  None      apache-pig
# 6        2015-01-01T00:02:02.050  27727389     3925941     3            None
# 7        2015-01-01T00:02:30.233  27727390     1004312     2            None
# 8        2015-01-01T00:02:32.123  27727391     4372672  None             ios
# 9        2015-01-01T00:02:57.983  27727393     2482149  None      sql-server
# 10       2015-01-01T00:03:31.337  27727394     4263870  None             php
# 11       2015-01-01T00:04:01.407  27727396     4409381  None         android
# 12       2015-01-01T00:04:02.813  27727397     4362545     2            None
# 13       2015-01-01T00:04:26.223  27727398      794088    13            None
# 14       2015-01-01T00:04:31.080  27727399      304326     1            None
# 15       2015-01-01T00:04:31.713  27727400     1457000     0            None
# 16       2015-01-01T00:04:40.350  27727402     4409377     1            None
# 17       2015-01-01T00:04:44.640  27727403     2141139     1            None
# 18       2015-01-01T00:05:02.697  27727405     1171516     0            None
# 19       2015-01-01T00:05:03.773  27727406      875317  None              c#
# 20       2015-01-01T00:05:27.167  27727407      821742  None            java
# 21       2015-01-01T00:05:34.733  27727408     2595033  None              c#
# 22       2015-01-01T00:06:17.720  27727409     1815395  None          apache
# 23       2015-01-01T00:06:41.067  27727410      541091  None           mysql
# 24       2015-01-01T00:06:45.510  27727411     1265856     0            None
# 25       2015-01-01T00:07:00.493  27727413     3456566     0            None
# 26       2015-01-01T00:07:28.747  27727414     1210038  None      javascript
# 27       2015-01-01T00:07:30.610  27727416      229371     1            None
# 28       2015-01-01T00:07:33.387  27727417     3225108     0            None
# 29       2015-01-01T00:07:39.243  27727418     3674356  None             php
# ...                          ...       ...         ...   ...             ...
# 5721305  2015-12-31T23:53:01.017  34552517     2744722     0            None
# 5721306  2015-12-31T23:53:52.380  34552519     5618866  None               c
# 5721307  2015-12-31T23:53:58.293  34552520      378185     0            None
# 5721308  2015-12-31T23:54:00.817  34552521     2196904    -1            None
# 5721309  2015-12-31T23:54:03.793  34552522     5735107     0            None
# 5721310  2015-12-31T23:54:06.107  34552523     5735065     0            None
# 5721311  2015-12-31T23:54:16.200  34552524     2925287     3            None
# 5721312  2015-12-31T23:54:18.083  34552526     4113680     3            None
# 5721313  2015-12-31T23:54:25.837  34552527      973158  None            html
# 5721314  2015-12-31T23:54:38.887  34552529      556573     5            None
# 5721315  2015-12-31T23:54:49.763  34552531     5600930     0            None
# 5721316  2015-12-31T23:54:59.740  34552532     4334304     0            None
# 5721317  2015-12-31T23:55:10.563  34552533     4468461     1            None
# 5721318  2015-12-31T23:56:12.397  34552535     2705042  None          vb.net
# 5721319  2015-12-31T23:56:16.013  34552536     4991888  None      javascript
# 5721320  2015-12-31T23:56:48.263  34552537     2310830     1            None
# 5721321  2015-12-31T23:57:01.880  34552538      434551     6            None
# 5721322  2015-12-31T23:57:03.073  34552539      441016  None  actionscript-3
# 5721323  2015-12-31T23:57:08.807  34552540     5377088  None           mysql
# 5721324  2015-12-31T23:57:18.833  34552541     4744359     3            None
# 5721325  2015-12-31T23:57:35.977  34552542     3880893     0            None
# 5721326  2015-12-31T23:57:36.433  34552543     1040740  None            java
# 5721327  2015-12-31T23:57:40.887  34552544       12711     5            None
# 5721328  2015-12-31T23:57:41.723  34552545     1432140     0            None
# 5721329  2015-12-31T23:57:59.083  34552546     1411249     0            None
# 5721330  2015-12-31T23:58:06.150  34552547     3909898  None             ios
# 5721331  2015-12-31T23:58:52.493  34552548     4706785     1            None
# 5721332  2015-12-31T23:59:30.960  34552549     1870790  None             c++
# 5721333  2015-12-31T06:02:40.277  34552827     2340452  None           flask
# 5721334  2015-12-14T11:38:43.200  34558009     2234058     2            None
#
#         Type ViewCount
# 0          A      None
# 1          A      None
# 2          A      None
# 3          Q       184
# 4          A      None
# 5          Q       180
# 6          A      None
# 7          A      None
# 8          Q       127
# 9          Q        62
# 10         Q       306
# 11         Q        96
# 12         A      None
# 13         A      None
# 14         A      None
# 15         A      None
# 16         A      None
# 17         A      None
# 18         A      None
# 19         Q       135
# 20         Q        77
# 21         Q       321
# 22         Q        95
# 23         Q       225
# 24         A      None
# 25         A      None
# 26         Q        80
# 27         A      None
# 28         A      None
# 29         Q      1047
# ...      ...       ...
# 5721305    A      None
# 5721306    Q        53
# 5721307    A      None
# 5721308    A      None
# 5721309    A      None
# 5721310    A      None
# 5721311    A      None
# 5721312    A      None
# 5721313    Q        15
# 5721314    A      None
# 5721315    A      None
# 5721316    A      None
# 5721317    A      None
# 5721318    Q        51
# 5721319    Q        39
# 5721320    A      None
# 5721321    A      None
# 5721322    Q        24
# 5721323    Q        24
# 5721324    A      None
# 5721325    A      None
# 5721326    Q        21
# 5721327    A      None
# 5721328    A      None
# 5721329    A      None
# 5721330    Q        29
# 5721331    A      None
# 5721332    Q       107
# 5721333    Q        12
# 5721334    A      None
#
# [5721335 rows x 7 columns]
# 0:05:54.195416

# %%
df.to_csv('step2_data.csv')

# %% [markdown]
# -----------------

# %% [markdown]
# ## Step 3. Putting it all together

# %% [markdown]
# We are now ready to tackle our original problem. Write a function to measure the similarity of the top 100 users with the highest answer scores. Compare the users based on the types of questions they answer. We will categorize a question by its first tag. You may choose to implement any one of the similarity/distance measures we discussed in class. **(30pts)**
#
# Note that answers are posts with `PostTypeId=2`. The ID of the question in answer posts is the `ParentId`.
#
# You may find the [sklearn.feature_extraction](http://scikit-learn.org/stable/modules/feature_extraction.html) module helpful.

# %%
t1 = datetime.now()

tree = 'stackoverflow-posts-2015.xml'
answerdfa = []
questiondfq = []       
for events, elem in ET.iterparse(tree, events=("start", "end")):
    answera = defaultdict(dict)
    questiona = defaultdict(dict) 
    try:
        if events == "start":
            if elem.attrib['PostTypeId']=='1':    
                questiona['Id'] = (elem.attrib['Id'])
                questiona['CreationDate']=(elem.attrib['CreationDate'])
                questiona['OwnerUserId']=(elem.attrib['OwnerUserId'])
                questiona['Tags']=(elem.attrib['Tags'].split('>')[0][1:])
                questiona['ViewCount']=(elem.attrib['ViewCount'])
                questiona['Score']= None
                questiona['Type']=('Q')
                questiondfq.append(questiona)
    
            if elem.attrib['PostTypeId']=='2':
                #answer['Id'] = (elem.attrib['Id'])
                #answer['CreationDate']=(elem.attrib['CreationDate'])
                answera['OwnerUserId']=(elem.attrib['OwnerUserId'])
                #answer['Tags']= None
                #answer['ViewCount']= None
                answera['Score']=(elem.attrib['Score'])
                answer['Type']= ('A')
                answera['ParentId']=(elem.attrib['ParentId'])
                answerdfa.append(answera)            
    except: None

        
        
# ###################################################################
# #Getting Top Hundred Users
# ###################################################################

df_a = DataFrame(answerdfa)
df_q = DataFrame(questiondfq)
df_a['Score'] = df_a['Score'].astype(int)
#df_a['ParentId'] = df_a['ParentId'].astype(obj)
#gb = df_a[['OwnerUserId','Score','ParentId']]
gb = df_a.groupby(['OwnerUserId']).sum()[['Score']].reset_index()
#gb = df_a.sum()[['Score']]
#print(gb)


gb = gb.sort_values(['Score'], axis=0, ascending=False)
gb = gb.head(n=100)
#print(gb)
top_id = gb['OwnerUserId'].tolist()
#print(top_id)
#gb.to_csv('top100score_data.csv')

###################################################################
#Getting Parent Ids of Top Hundred Users
###################################################################

top_user_parent_ids = { 'userId': None, 'parentIdList': None }
for myId in top_id:
    condition = df_a['OwnerUserId'] == myId
    wanted_rows = df_a[condition]
    parent_ids = wanted_rows['ParentId'].tolist()
    top_user_parent_ids[myId] = parent_ids
    #print(parent_ids)
#print(top_user_parent_ids)
# #[top_user_parent_ids.get(values) for value in values]

# ##################################################################
# #Getting Tags of Top Hundred Users
# ###################################################################

df_tags = df_q[['Id','Tags']]
# print(df_tags)
top_user_tags = { 'userId': None, 'Tags': None }
for myId in top_id:
    parent_ids = top_user_parent_ids[myId]
    for parent_id in parent_ids:
        condition = df_tags['Id'] == parent_id
        #print(df_tags['Id'].dtype)
        wanted_rows = df_tags[condition]
        #print(wanted_rows)
        tags = wanted_rows['Tags'].tolist()
        #print("UserId: ", myId)
        #print("\tParentId: ", parent_id)
        #print("\t\tTags: ", tags)
    top_user_tags[myId] = tags
        #print(top_user_tags[myId])
        

print(top_user_tags)

######################################################################

# dictionary with user --> [question id] Done  (top_user_qs_ids)
# question id --> tags Done (df_tags_dict)

# df_tags = df_q[['Id','Tags']]
# df_tags_dict = area_dict = dict(zip(df_tags.Id, df_tags.Tags))
# # # print(df_tags_dict)
# # #dictioanary user --> tags

# df_tags = df_q[['Id','Tags']]
# user_tags_dict = {}
# print(df_tags_dict)
# print(top_user_parent_ids)
# for key1, elem1 in top_user_parent_ids.items():
#     for question in elem1:
#         tag = df_tags_dict[question]
#         user_tags_dict[key1] = tag

######################################################################




###################################################################

# parent_ids_list =list(top_user_parent_ids.values())
#print(parent_ids_list)

#for parent_ids in parent_ids_list:
#print(df_tags[df_tags['Id'].isin(parent_ids_list[0][0])])
    
    
    
    
# #     print(parent_ids)
# #     print(df_tags['Id'])
#     x = df_tags.loc[df_tags['Id'] == '31604187', 'Tags']
#     print(x)
    

# for parent_id in top_user_parent_ids.values():
#     print(df_tags)
#     print(parent_id)
#     if df_tags['Id'] == parent_id:
#         wanted_rows = df_tags[parent_id]
#         print(wanted_rows)
#         #tags = wanted_rows['Tags'].tolist()
#         #print("UserId: ", myId)
# #     #print("\tParentId: ", parent_id)
# #         print("\t\tTags: ", tags)
# #         top_user_tags[myId] = tags


#print(df_tags['Tags'][1])
#row_mask = df_tags.isin(top_user_parent_ids.values())
#print(df_tags[row_mask])

# lista = top_user_parent_ids.values()
# print(lista)

#x = sorted(top_user_parent_ids.items(), key=lambda i: i[1][2])
#print(x)



# tag_list = list(top_user_tags.values())
# print(tag_list)
# t = df_tags['Id'].tolist()
# print(top_user_parent_ids.values([0]))
# print(t)
# for parent_id in top_user_parent_ids.values():
#     print(t)
#     print(parent_id)
#     if df_tags['Id'] == parent_id:
#     #condition = df_tags['Id'] == parent_id
#         wanted_rows = df_tags['Id']
#         tags = wanted_rows['Tags'].tolist()
#     #print("UserId: ", myId)
#     #print("\tParentId: ", parent_id)
#         print("\t\tTags: ", tags)
#         top_user_tags[myId] = tags

# print(top_user_tags)
# # tag_list = list(top_user_tags.values())
# # print(tag_list)
# # #tags = [top_user_tags[myId] for parent_id in parent_ids]

#print(parent_ids)
# t2 = datetime.now()
# print(t2-t1)
# Out:
# {'1221571': ['android'], '1009479': ['c++'], '341994': ['ios'], '131872': ['java'], '440558': ['c++'], '3933332': ['php'], '1187415': ['ios'], '276052': [], '6309': ['git'], '2141635': ['python'], '522444': ['java'], '3001626': ['regex'], '548225': ['apache'], '335858': ['java'], '1743880': ['java'], '613130': ['c++'], '22656': ['c++'], '496161': ['c++11'], '2586922': ['arrays'], '204847': ['c++'], '519413': ['javascript'], 'userId': None, '3297613': ['python'], '560648': ['c++'], 'Tags': None, '704848': ['python'], '85371': ['c++'], '15168': ['c'], '3832970': ['java'], '2756719': ['c++'], '139985': ['java'], '1505939': ['c'], '218196': ['javascript'], '1903366': ['php'], '1566221': ['algorithm'], '14860': ['mysql'], '2173917': ['c'], '155423': ['opencv'], '3679490': ['javascript'], '981959': ['c++'], '438154': ['java'], '2877241': ['c'], '2422776': ['mysql'], '100297': ['python'], '589924': ['perl'], '1774667': ['c++'], '1064245': ['ant'], '2069064': [], '157247': ['javascript'], '795990': ['python'], '1708801': ['c++'], '69083': ['sql-server'], '190597': ['python'], '57695': ['java'], '434551': ['c'], '1048572': ['javascript'], '992484': ['java'], '19068': ['javascript'], '1705598': ['pointers'], '1983495': ['c'], '2296458': ['c++'], '17034': ['c#'], '5070879': ['sql'], '115145': ['android'], '2867928': ['python'], '3293881': ['python'], '1501794': ['java'], '284240': ['c#'], '157882': ['jsf'], '2025923': ['javascript'], '2380830': ['c++'], '3732271': ['r'], '1707091': ['java'], '65863': ['c'], '841108': ['compiler-construction'], '771848': ['python'], '1870803': ['c#'], '816620': ['javascript'], '1903116': ['python'], '2680216': ['css'], '1529630': ['javascript'], '4301306': ['bash'], '1491895': ['node.js'], '2435473': ['javascript'], '4856258': [], '2372064': ['r'], '993547': ['c#'], '104349': ['python'], '949476': ['javascript'], '571407': ['java'], '114251': ['javascript'], '505088': ['c#'], '3250829': ['matlab'], '1144035': ['sql-server'], '1782465': ['c++'], '2455888': ['c'], '2606013': ['css'], '462627': ['javascript'], '2970947': ['java'], '661519': ['c++'], '1159478': ['c#'], '2711488': ['filter']}

# %%
print(parent_ids)
# Out:
# ['27751378', '27762143', '27773881', '27782623', '27787071', '27788184', '27788519', '27812286', '27831970', '27847940', '27846785', '27850344', '27854647', '27855323', '27868561', '27868741', '27872683', '27892140', '27891268', '27906082', '27907246', '27925341', '27929906', '27951732', '27951377', '27957119', '27971486', '27970782', '27972021', '27957378', '27976243', '27988918', '27996548', '27996586', '27997179', '28006055', '28007684', '28008177', '28008240', '28011196', '28010906', '28012488', '28015539', '28017341', '28033008', '28052725', '28051862', '28053096', '28058501', '28074895', '28075988', '28077887', '28093275', '28093310', '28093329', '28094065', '28094310', '28094645', '28093925', '28095966', '28095821', '28098211', '28118500', '28157512', '28157752', '28158179', '28163979', '28179101', '28179542', '28180374', '28183034', '28177529', '28200064', '28200410', '28200689', '28200982', '28205184', '28206129', '28207223', '28207382', '28208649', '28221907', '28223363', '28226555', '28225777', '28226914', '28227467', '28228163', '28244053', '28244154', '28246760', '28247081', '28248457', '28248959', '28248549', '28258010', '28258685', '28269170', '28269260', '28271273', '28272464', '28272540', '28278930', '28279378', '28287827', '28287776', '28289078', '28292017', '28304333', '28307041', '28307666', '28307940', '28305685', '28327738', '28326736', '28328489', '28328811', '28330833', '28330974', '28331495', '28334055', '28336672', '28336903', '28337453', '28354084', '28355667', '28356354', '28358549', '28369158', '28373962', '28399065', '28400128', '28402910', '28441553', '28442355', '28442428', '28447343', '28465127', '28487504', '28482274', '28491632', '28506456', '28634638', '28636400', '28641395', '28658730', '28665697', '28679760', '28681330', '28684079', '28687806', '28688402', '28688602', '28687086', '28684645', '28707310', '28711240', '28683769', '28724396', '28731568', '28731818', '28731763', '28732992', '28734651', '28735030', '28735511', '28735366', '28752805', '28755617', '28751497', '28757108', '28756618', '28772877', '28772969', '28774591', '28777626', '28777667', '28777654', '28784321', '28801456', '28801212', '28820260', '28820338', '28839829', '28949372', '28950432', '28955397', '28970939', '28996926', '29014362', '29024131', '29043090', '29127299', '29130237', '29131536', '29133567', '29152654', '29152717', '29154731', '29155020', '29170307', '29191379', '29236654', '29237136', '29262564', '29265314', '29265944', '29265172', '29267590', '29280246', '29283205', '29267760', '29284968', '29289046', '29388886', '29434908', '29453622', '29542738', '29546295', '29566821', '29568831', '29569126', '29569852', '29572392', '29593881', '29596924', '29616207', '29629089', '29637755', '29639343', '29639093', '29657075', '29658298', '29659396', '29659989', '29661269', '29662969', '29665231', '29678435', '29678929', '29681516', '29683588', '29684709', '29690068', '29703922', '29706764', '29710049', '29710788', '29711907', '29722563', '29724011', '29724659', '29724957', '29725049', '29725265', '29731215', '29733257', '29733960', '29733618', '23807085', '29735889', '29739860', '29750960', '29753756', '29754624', '29755556', '29776497', '29776802', '29779342', '29781030', '29782140', '29782587', '29785386', '29785573', '29787452', '29787428', '29809036', '29807080', '29826066', '29823919', '29830302', '29831535', '29831480', '29843945', '29903961', '29932558', '29996477', '30004331', '30005785', '30016817', '30023223', '30035955', '30038721', '30038466', '30039465', '14846547', '30039966', '30040348', '30055745', '30061060', '30062810', '30062516', '30066255', '30071885', '30079720', '30062187', '30085487', '30085840', '30088256', '30088919', '30089698', '30091022', '30091742', '30102119', '30107702', '30108105', '30106206', '30109802', '30113400', '30127711', '30127019', '30131327', '26064649', '30131542', '30128705', '30146686', '30146723', '30146970', '30147455', '30153768', '30153552', '30157111', '30157331', '30 ...

# %%
# #################################################################
# Getting Distance Matrix of Top Hundred Users
# ##################################################################

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import euclidean_distances

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(top_user_tags)
X = X.toarray()
# print(X)
dtm = euclidean_distances(X)
print(dtm)
# Out:
# [[ 0.          1.41421356  1.41421356 ...,  1.41421356  1.41421356
#    1.41421356]
#  [ 1.41421356  0.          1.41421356 ...,  1.41421356  1.41421356
#    1.41421356]
#  [ 1.41421356  1.41421356  0.         ...,  1.41421356  1.41421356
#    1.41421356]
#  ...,
#  [ 1.41421356  1.41421356  1.41421356 ...,  0.          1.41421356
#    1.41421356]
#  [ 1.41421356  1.41421356  1.41421356 ...,  1.41421356  0.          1.41421356]
#  [ 1.41421356  1.41421356  1.41421356 ...,  1.41421356  1.41421356  0.        ]]

# %% [markdown]
# Plot the distance of the top 100 users using a [heatmap](https://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.heatmap.html). **(5 pts)**

# %%
import matplotlib.pyplot as plt
#plot=sns.heatmap(distmat, xticklabels= False, yticklabels=False)
ax = sns.heatmap(dtm, xticklabels=False, yticklabels=False)
plt.show()

# %% [markdown]
# Provide an interpretation of the heatmap's results in the following markdown cell. **(5 pts)**

# %%
dtm.to_csv('userid_data.csv')

# %% [markdown]
# -----------------
